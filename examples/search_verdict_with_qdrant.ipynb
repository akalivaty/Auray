# %%
import os

import dotenv

dotenv.load_dotenv()
HF_ACCESS_TOKEN = os.getenv("HF_ACCESS_TOKEN")
ROOT_PATH = os.path.expanduser(os.getenv("ROOT_PATH"))
ROOT_PATH
# Out:
# '/home/yuva/dev/LLM_Examples'

# %% [markdown]
# # Build HF embedding

# %%
from langchain_huggingface import HuggingFaceEmbeddings

# https://huggingface.co/spaces/mteb/leaderboard
sentence_transformer_models = [
    "sentence-transformers/all-MiniLM-L6-v2",
    "lier007/xiaobu-embedding-v2",  # rank 1 in chinese
    "Alibaba-NLP/gte-large-en-v1.5",  # rank 21 in english
    # "iampanda/zpoint_large_embedding_zh", # rank 4 in chinese
    # "dunzhang/stella_en_400M_v5", # rank 6 in english  (deprecated)
]

sentence_transformer_model = sentence_transformer_models[1]

hf_embeddings_model = HuggingFaceEmbeddings(
    model_name=sentence_transformer_model,
    cache_folder=os.path.join(ROOT_PATH, "sentence_transformer_model"),
    model_kwargs={"trust_remote_code": True},
)
# Out:
# /home/yuva/dev/LLM_Examples/.venv/lib/python3.11/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %% [markdown]
# # Build HF vector database

# %%
import re

from langchain_community.document_loaders import PyPDFLoader
from langchain_community.vectorstores import Qdrant
from langchain_text_splitters import (
    MarkdownHeaderTextSplitter,
    RecursiveCharacterTextSplitter,
)

document_root_path = os.path.join(ROOT_PATH, "docs")
documents = [
    "CNS16190-zh_TW.md",  # 0
    "CNS16190-zh_TW_only_provision.md",  # 1
    "CNS16190-zh_TW_only_provision.pdf",  # 2
    "ts_103701_only_test_scenario.pdf",  # 3
    "ts_103701_only_test_scenario.md",  # 4
    "en_303645_only_provision.pdf",  # 5
]
document_idx = 4  # <-- only change this

chunk_size = 1000
chunk_overlap = 200
model_alias = re.split("[-_]", re.split("/", sentence_transformer_model)[-1])[0]
embedding_cache_path = os.path.join(ROOT_PATH, "embedding_cache")

mode = documents[document_idx].split(".")[-1]
db_collection_names = [
    f"CNS16190_{mode}_hf_{model_alias}_emb",
    f"TS103701_{mode}_hf_{model_alias}_emb",
    f"EN303645_{mode}_hf_{model_alias}_emb",
]
db_collection_idx = db_collection_idx = next(
    (
        idx
        for idx, item in enumerate(db_collection_names)
        if item[:2].casefold() == documents[document_idx][:2].casefold()
    ),
    -1,
)

if os.path.isdir(
    os.path.join(
        embedding_cache_path, "collection", db_collection_names[db_collection_idx]
    )
):
    # database already exists, load it
    hf_vectorstore = Qdrant.from_existing_collection(
        embedding=hf_embeddings_model,
        path=embedding_cache_path,
        collection_name=db_collection_names[db_collection_idx],
    )
else:
    # database does not exist, create it
    try:
        if mode == "md":
            splits = None
            with open(
                os.path.join(document_root_path, documents[document_idx]), "r"
            ) as f:
                markdown_document = f.read()

                headers_to_split_on = [
                    ("#", "Header 1"),
                    ("##", "Header 2"),
                    ("###", "Header 3"),
                    ("####", "Header 4"),
                ]

                markdown_splitter = MarkdownHeaderTextSplitter(headers_to_split_on)
                splits = markdown_splitter.split_text(markdown_document)

        elif mode == "pdf":
            pdf_loader = PyPDFLoader(
                os.path.join(document_root_path, documents[document_idx])
            )
            pdf_doc = pdf_loader.load()
            pdf_text_splitter = RecursiveCharacterTextSplitter(
                chunk_size=chunk_size, chunk_overlap=chunk_overlap
            )
            splits = pdf_text_splitter.split_documents(documents=pdf_doc)

    except Exception as e:
        print(f"An error occurred when the vectorstore createing: {e}")

    finally:
        hf_vectorstore = Qdrant.from_documents(
            splits,
            embedding=hf_embeddings_model,
            path=embedding_cache_path,
            collection_name=db_collection_names[db_collection_idx],
        )

# %% [markdown]
# ### MarkdownHeaderTextSplitter (for testing)

# %%
import os

import dotenv
from langchain_text_splitters import MarkdownHeaderTextSplitter

dotenv.load_dotenv()
ROOT_PATH = os.path.expanduser(os.getenv("ROOT_PATH"))

document_root_path = os.path.join(ROOT_PATH, "docs")
md_header_splits = None
with open(
    os.path.join(document_root_path, "ts_103701_only_test_scenario.md"), "r"
) as f:
    markdown_document = f.read()

    headers_to_split_on = [
        ("#", "Header 1"),
        ("##", "Header 2"),
        ("###", "Header 3"),
        ("####", "Header 4"),
    ]

    markdown_splitter = MarkdownHeaderTextSplitter(headers_to_split_on)
    md_header_splits = markdown_splitter.split_text(markdown_document)

len(md_header_splits), md_header_splits
# Out:
# (392,
#  [Document(metadata={'Header 1': '5.0 TSO 4: Reporting implementation', 'Header 2': '5.0.1 Test group 4-1', 'Header 3': '5.0.1.0 Test group objective'}, page_content='The test group addresses the provision 4-1.'),
#   Document(metadata={'Header 1': '5.0 TSO 4: Reporting implementation', 'Header 2': '5.0.1 Test group 4-1', 'Header 3': '5.0.1.1 Test Case 4-1-1 (Conceptual)', 'Header 4': 'Test purpose'}, page_content='The purpose of this test case is the conceptual assessment of the justifications for recommendations that are considered to be not applicable for or not fulfilled by the DUT.'),
#   Document(metadata={'Header 1': '5.0 TSO 4: Reporting implementation', 'Header 2': '5.0.1 Test group 4-1', 'Header 3': '5.0.1.1 Test Case 4-1-1 (Conceptual)', 'Header 4': 'Test units'}, page_content='a) The TL **shall** check whether a justification is given in the ICS for each recommendation that is considered to be not applicable for or not fulfilled by the DUT.'),
#   Document(metadata={'Header 1': '5.0 TSO 4: Reporting implementation', 'Header 2': '5.0.1 Test group 4-1', 'Header 3': '5.0.1.1 Test Case 4-1-1 (Conceptual)', 'Header 4': 'Assignment of verdict'}, page_content='The verdict PASS is assigned if:  \n- a justification is given for every recommendation that is considered to be not applicable for the DUT; and\n- a justification is given for every recommendation that is considered to be not fulfilled by the DUT.  \nThe verdict FAIL is assigned otherwise.'),
#   Document(metadata={'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.1 Test group 5.1-1', 'Header 3': '5.1.1.0 Test group objective'}, page_content='The test group addresses the provision 5.1-1.  \nThis test group addresses all states of the DUT with the exception of factory default.'),
#   Document(metadata={'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.1 Test group 5.1-1', 'Header 3': '5.1.1.1 Test case 5.1-1-1 (conceptual)', 'Header 4': 'Test purpose'}, page_content='The purpose of this test case is the conceptual assessment of the password-based authentication mechanisms.'),
#   Document(metadata={'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.1 Test group 5.1-1', 'Header 3': '5.1.1.1 Test case 5.1-1-1 (conceptual)', 'Header 4': 'Test units'}, page_content='a) The TL **shall** assess for all password-based user authentication mechanisms in IXIT 1-AuthMech where passwords are not defined by the user according to "Authentication Factor" and used in any state other than the factory default whether the "Password Generation Mechanism" ensures that passwords are unique per device.'),
#   Document(metadata={'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.1 Test group 5.1-1', 'Header 3': '5.1.1.1 Test case 5.1-1-1 (conceptual)', 'Header 4': 'Assignment of verdict'}, page_content='The verdict PASS is assigned if:  \n- each password of a password-based authentication mechanism being used in any state other than the factory default, that is not defined by the user, is unique per device.  \nThe verdict FAIL is assigned otherwise.'),
#   Document(metadata={'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.1 Test group 5.1-1', 'Header 3': '5.1.1.2 Test case 5.1-1-2 (functional)', 'Header 4': 'Test purpose'}, page_content='The purpose of this test case is the functional assessment of the password-based authentication mechanisms concerning the completeness of the IXIT documentation a), the passwords defined by the user b) and the generation mechanisms c).'),
#   Document(metadata={'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.1 Test group 5.1-1', 'Header 3': '5.1.1.2 Test case 5.1-1-2 (functional)', 'Header 4': 'Test units'}, page_content='a) The TL **shall** functionally assess whether password-based authentication mechanisms that are not documented in IXIT 1-AuthMech are available via a network interface on the DUT or described in the user manual.  \nEXAMPLE: Network scanning tools allow for discovery of network-based authentication mechanisms.  \nb) For each password-based user authentication mechanism in IXIT 1-AuthMech, the TL **shall** functionally check whether the user is required to define all passwords that are user-defined according to "Authentication Factor" before being used.  \nc) The TL **shall** functionally assess whether all passwords of the DUT, that are not defined by the user according to "Authentication Factor" in IXIT 1-AuthMech and used in any state other than the factory default, do not violate the description of the "Password Generation Mechanism".'),
#   Document(metadata={'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.1 Test group 5.1-1', 'Header 3': '5.1.1.2 Test case 5.1-1-2 (functional)', 'Header 4': 'Assignment of verdict'}, page_content='The verdict PASS is assigned if:  \n- every discovered password-based authentication mechanism is documented in the IXIT; and\n- the user is required to define all passwords before being used, that are stated as defined by the user in the IXIT;\nand\n- there is no indication that the generation of a not user-defined password of the DUT used in any state other than the factory default differs from the generation mechanism described in the IXIT.  \nThe verdict FAIL is assigned otherwise.'),
#   Document(metadata={'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.2 Test Group 5.1-2', 'Header 3': '5.1.2.0 Test group objective'}, page_content='The test group addresses the provision 5.1-2.'),
#   Document(metadata={'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.2 Test Group 5.1-2', 'Header 3': '5.1.2.1 Test case 5.1-2-1 (conceptual)', 'Header 4': 'Test purpose'}, page_content='The purpose of this test case is the conceptual assessment of the generation mechanisms of pre-installed passwords.'),
#   Document(metadata={'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.2 Test Group 5.1-2', 'Header 3': '5.1.2.1 Test case 5.1-2-1 (conceptual)', 'Header 4': 'Test units'}, page_content='a) The TL **shall** assess for each authentication mechanism in IXIT 1-AuthMech using pre-installed passwords according to "Authentication Factor", whether the generation mechanism in "Password Generation Mechanism" induces obvious regularities in the resulting passwords.  \nNOTE 1: Incremental counters (such as "password1", "password2" and so on) can be obvious regularities.  \nb) The TL **shall** assess whether the generation mechanism induces common strings or other common patterns in the resulting passwords.  \nNOTE 2: Common strings can be those contained in password dictionaries, such as for example:\n<https://www.ncsc.gov.uk/static-assets/documents/PwnedPasswordsTop100k.txt>.  \nc) The TL **shall** assess whether the generation mechanism induces passwords, that are related in an obvious way to public information.  \nNOTE 3: Public information can be MAC addresses, Wi-Fi® SSIDs, name, type and description of the device.  \nd) The TL **shall** assess whether the generation mechanism induces passwords, that are considered appropriate in terms of complexity.  \nNOTE 4: In this context complexity is linked to the probability of guessing the password while applying the information an attacker has. The length of a password is one important aspect to consider for a password\'s complexity.'),
#   Document(metadata={'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.2 Test Group 5.1-2', 'Header 3': '5.1.2.1 Test case 5.1-2-1 (conceptual)', 'Header 4': 'Assignment of verdict'}, page_content='The verdict PASS is assigned if:  \n- no obvious regularities in pre-installed passwords are found; and\n- no common strings or other common patterns in pre-installed passwords are found; and\n- the generation mechanisms for pre-installed passwords do not induce passwords, that are related in an obvious way to public information; and\n- the generation mechanisms for pre-installed passwords are considered appropriate in terms of complexity.  \nThe verdict FAIL is assigned otherwise.'),
#   Document(metadata={'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.2 Test Group 5.1-2', 'Header 3': '5.1.2.2 Test case 5.1-2-2 (functional)', 'Header 4': 'Test purpose'}, page_content='The purpose of this test case is the functional assessment of the generation mechanisms of pre-installed passwords.  \na) For each authentication mechanism in IXIT 1-AuthMech using pre-installed passwords according to\n"Authentication Factor", the TL **shall** functionally assess whether the generation mechanism is plausibly implemented in accordance to the description in "Password Generation Mechanism".  \nEXAMPLE: The description of the "Password Generation Mechanism" states, that passwords consist of 8 digits containing at least one character of each group uppercase letters, lowercase letters and numbers.The verification that the corresponding passwords of the DUT match the given length of 8 digits, containing at least one character of the stated groups and do not contain special characters can be helpful to collect an indication.'),
#   Document(metadata={'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.2 Test Group 5.1-2', 'Header 3': '5.1.2.2 Test case 5.1-2-2 (functional)', 'Header 4': 'Assignment of verdict'}, page_content='The verdict PASS is assigned if:  \n- for each pre-installed password there is no indication, that its generation differs from the generation mechanism described in the IXIT.  \nThe verdict FAIL is assigned otherwise.'),
#   Document(metadata={'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.3 Test Group 5.1-3', 'Header 3': '5.1.3.0 Test Group Objective'}, page_content='The test group addresses the provision 5.1-3.  \nAccording to ETSI TS 103 645 [1]/ETSI EN 303 645 [2] best practice cryptography is defined as cryptography that is suitable for the corresponding use case and has no indication of a feasible attack with current readily available techniques.  \nThe objective of this test group is to assess, firstly, whether the cryptographic methods provide the security guarantees that are necessary for the authentication mechanisms and, secondly, whether the cryptographic methods are not known to be vulnerable to a feasible attack.'),
#   Document(metadata={'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.3 Test Group 5.1-3', 'Header 3': '5.1.3.1 Test case 5.1-3-1 (conceptual)', 'Header 4': 'Test purpose'}, page_content='The purpose of this test case is the conceptual assessment of the cryptography used for the authentication mechanisms concerning the use of best practice cryptography (a-c) and the vulnerability to a feasible attack d).'),
#   Document(metadata={'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.3 Test Group 5.1-3', 'Header 3': '5.1.3.1 Test case 5.1-3-1 (conceptual)', 'Header 4': 'Test units'}, page_content='a) For each authentication mechanism in IXIT 1-AuthMech used to authenticate users against the DUT, the TL\nshall assess whether the "Security Guarantees" are appropriate for the use case of user authentication, at least integrity and authenticity are required to be fulfilled.  \nb) For each authentication mechanism in IXIT 1-AuthMech used to authenticate users against the DUT, the TL\nshall assess whether the mechanism according to "Description" is appropriate to achieve the "Security Guarantees".  \nNOTE 1: A holistic approach is required to assess the security of the mechanism.  \nc) For each authentication mechanism in IXIT 1-AuthMech used to authenticate users against the DUT, the TL **shall** assess whether the "Cryptographic Details" are considered as best practice cryptography for the use case of user authentication based on a reference catalogue. If "Cryptographic Details" are not included in a reference catalogue for the corresponding use case (e.g. novel cryptography), the SO **shall** provide evidences, e.g. a risk analysis, to justify the cryptography is appropriate as best practice for the use case. In such case the TL **shall** assess whether the evidence is appropriate and reliable for the use case.  \nNOTE 2: A use case based list of examples for best practice cryptography is given in ETSI TR 103 621 [i.7]. Moreover general reference catalogues of best practice cryptography are available, for example:  \n- SOGIS Agreed Cryptographic Mechanisms (<https://www.sogis.eu>).  \nNOTE 3: A cryptographic algorithm or primitive that is deprecated with regard to its desired security property (e.g. SHA1 for collision resistance) or that relies on a cryptographic parameter (e.g. key-size) that is not appropriate, taking into account the intended lifetime of the DUT and cryptoagility, cannot be considered as best practice cryptography.  \nd) For each authentication mechanism in IXIT 1-AuthMech used to authenticate users against the DUT, the TL shall assess whether the "Cryptographic Details" are not known to be vulnerable to a feasible attack for the desired security property on the base of the "Security Guarantees" by reference to competent cryptanalytic reports.  \nNOTE 4: Competent cryptanalytic reports are typically published in the scientific literature or, alternatively, are to be provided by the SO. Further, clause D.2 provides information about the expected attack potential for level basic.'),
#   Document(metadata={'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.3 Test Group 5.1-3', 'Header 3': '5.1.3.1 Test case 5.1-3-1 (conceptual)', 'Header 4': 'Assignment of verdict'}, page_content='The verdict PASS is assigned if for all user authentication mechanisms:  \n- the security guarantees are appropriate for the use case of user authentication; and\n- the mechanism is appropriate to achieve the security guarantees with respect to the use case; and\n- all used cryptographic details are considered as best practice for the use case; and\n- all used cryptographic details are not known to be vulnerable to a feasible attack for the desired security property.  \nThe verdict FAIL is assigned otherwise.'),
#   Document(metadata={'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.3 Test Group 5.1-3', 'Header 3': '5.1.3.2 Test Case 5.1-3-2 (Functional)', 'Header 4': 'Test purpose'}, page_content='The purpose of this test case is the functional assessment of the cryptography used for the authentication mechanisms.'),
#   Document(metadata={'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.3 Test Group 5.1-3', 'Header 3': '5.1.3.2 Test Case 5.1-3-2 (Functional)', 'Header 4': 'Test units'}, page_content='a) For each authentication mechanism in IXIT 1-AuthMech used to authenticate users against the DUT, the TL\nshall functionally assess whether the described "Cryptographic Details" are used by the DUT.  \nEXAMPLE 1: Using a protocol analyser or packet sniffer tool for network-based mechanisms. EXAMPLE 2: If a PKI certificate based authentication is used, sniffing the used certificates and comparing the properties with the described cryptography in the IXIT can be helpful to collect an indication.  \nEXAMPLE 3: If the underlying communication protocol of the authentication mechanism enables different security modes for the communication, trying to downgrade the security mode can be helpful to collect an indication.'),
#   Document(metadata={'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.3 Test Group 5.1-3', 'Header 3': '5.1.3.2 Test Case 5.1-3-2 (Functional)', 'Header 4': 'Assignment of verdict'}, page_content='The verdict PASS is assigned if:  \n- there is no indication that any used cryptographic setting differs from its IXIT documentation.  \nThe verdict FAIL is assigned otherwise.'),
#   Document(metadata={'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.4 Test Group 5.1-4', 'Header 3': '5.1.4.0 Test group objective'}, page_content='The test group addresses the provision 5.1-4.'),
#   Document(metadata={'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.4 Test Group 5.1-4', 'Header 3': '5.1.4.1 Test case 5.1-4-1 (conceptual)', 'Header 4': 'Test purpose'}, page_content='The purpose of this test case is the conceptual assessment of the mechanisms to change authentication values.'),
#   Document(metadata={'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.4 Test Group 5.1-4', 'Header 3': '5.1.4.1 Test case 5.1-4-1 (conceptual)', 'Header 4': 'Test units'}, page_content='a) The TL **shall** assess whether for every authentication mechanism in IXIT 1-AuthMech where "Description" indicates that the mechanism is used for user authentication, the resource of "Documentation of Change Mechanisms" in IXIT 2-UserInfo considers the mechanism and describes how to change the authentication value for the mechanism in a manner that is understandable for a user with limited technical knowledge\n(see clause D.3).'),
#   Document(metadata={'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.4 Test Group 5.1-4', 'Header 3': '5.1.4.1 Test case 5.1-4-1 (conceptual)', 'Header 4': 'Assignment of verdict'}, page_content='The verdict PASS is assigned if:  \n- for all user based authentication mechanisms the published resource describes how to change the authentication value with a simple mechanism.  \nThe verdict FAIL is assigned otherwise.'),
#   Document(metadata={'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.4 Test Group 5.1-4', 'Header 3': '5.1.4.2 Test case 5.1-4-2 (functional)', 'Header 4': 'Test purpose'}, page_content='The purpose of this test case is the functional assessment of the mechanisms to change authentication values.'),
#   Document(metadata={'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.4 Test Group 5.1-4', 'Header 3': '5.1.4.2 Test case 5.1-4-2 (functional)', 'Header 4': 'Test units'}, page_content='a) The TL **shall** perform a change of the authentication values for all user authentication mechanisms in IXIT 1-AuthMech as documented in the resource from "Documentation of Change Mechanisms" in IXIT 2-UserInfo.  \nb) The TL **shall** functionally assess whether all changes of user authentication values are successful.  \nEXAMPLE: The old authentication value is no longer valid and the new authentication value is valid after a change.'),
#   Document(metadata={'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.4 Test Group 5.1-4', 'Header 3': '5.1.4.2 Test case 5.1-4-2 (functional)', 'Header 4': 'Assignment of verdict'}, page_content='The verdict PASS is assigned if:  \n- all mechanisms for the user to change authentication values for user authentication mechanisms work as described.  \nThe verdict FAIL is assigned otherwise.'),
#   Document(metadata={'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.5 Test Group 5.1-5', 'Header 3': '5.1.5.0 Test group objective'}, page_content='The test group addresses the provision 5.1-5.'),
#   Document(metadata={'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.5 Test Group 5.1-5', 'Header 3': '5.1.5.1 Test case 5.1-5-1 (conceptual)', 'Header 4': 'Test purpose'}, page_content='The purpose of this test case is the conceptual assessment of the mechanisms to make brute force attacks via network interfaces impracticable.'),
#   Document(metadata={'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.5 Test Group 5.1-5', 'Header 3': '5.1.5.1 Test case 5.1-5-1 (conceptual)', 'Header 4': 'Test units'}, page_content='a) The TL **shall** assess whether for each authentication mechanism in IXIT 1-AuthMech, where "Description" indicates that the mechanism is directly addressable via a network interface, the mechanism in "Brute Force Prevention" makes brute force attacks via network interfaces impracticable.  \nNOTE 1: Methods to mitigate brute force attacks are, among others:  \n- Time delays between consecutive failed attempts to authenticate.\n- A limited number of authentication attempts, followed by a suspension period where no login is allowed.\n- A limited number of authentication attempts, followed by locking the authentication mechanism.\n- Appropriate entropy for authentication values based on best practice cryptography.\n- Two-factor authentication.  \nNOTE 2: There are best practices for brute force protection available, e.g. <https://owasp.org/wwwcommunity/controls/Blocking_Brute_Force_Attacks>.'),
#   Document(metadata={'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.5 Test Group 5.1-5', 'Header 3': '5.1.5.1 Test case 5.1-5-1 (conceptual)', 'Header 4': 'Assignment of verdict'}, page_content='The verdict PASS is assigned if:  \n- the documented mechanisms make brute force attacks via network interfaces impracticable.  \nThe verdict FAIL is assigned otherwise.'),
#   Document(metadata={'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.5 Test Group 5.1-5', 'Header 3': '5.1.5.2 Test case 5.1-5-2 (functional)', 'Header 4': 'Test purpose'}, page_content='The purpose of this test case is the functional assessment of the mechanisms to make brute force attacks via network interfaces impracticable concerning the completeness of the IXIT documentation a) and the corresponding mechanisms b).'),
#   Document(metadata={'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.5 Test Group 5.1-5', 'Header 3': '5.1.5.2 Test case 5.1-5-2 (functional)', 'Header 4': 'Test units'}, page_content='a) The TL **shall** functionally assess whether there exist further network-based authentication mechanisms, that are not listed in IXIT 1-AuthMech.  \nNOTE: Methods for functionally checking for network-based authentication methods include network scanners such as "nmap", or wireless sniffers such as a BLE dongle.  \nb) The TL **shall** attempt to brute force every network-based authentication mechanisms described in IXIT 1-AuthMech.'),
#   Document(metadata={'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.5 Test Group 5.1-5', 'Header 3': '5.1.5.2 Test case 5.1-5-2 (functional)', 'Header 4': 'Assignment of verdict'}, page_content='The verdict PASS is assigned if:  \n- ever discovered network-based authentication mechanism is documented in the IXIT; and\n- for all authentication mechanism via network interfaces there is no indication that the implementation of brute force prevention differs from its IXIT documentation.  \nThe verdict FAIL is assigned otherwise.'),
#   Document(metadata={'Header 1': '5.2 TSO 5.2: Implement a means to manage reports of vulnerabilities', 'Header 2': '5.2.1 Test group 5.2-1', 'Header 3': '5.2.1.0 Test group objective'}, page_content='The test group addresses the provision 5.2-1.'),
#   Document(metadata={'Header 1': '5.2 TSO 5.2: Implement a means to manage reports of vulnerabilities', 'Header 2': '5.2.1 Test group 5.2-1', 'Header 3': '5.2.1.1 Test case 5.2-1-1 (conceptual)', 'Header 4': 'Test purpose'}, page_content='The purpose of this test case is the conceptual assessment of the publication of the vulnerability disclosure policy.'),
#   Document(metadata={'Header 1': '5.2 TSO 5.2: Implement a means to manage reports of vulnerabilities', 'Header 2': '5.2.1 Test group 5.2-1', 'Header 3': '5.2.1.1 Test case 5.2-1-1 (conceptual)', 'Header 4': 'Test units'}, page_content='a) The TL **shall** assess whether access to the publication as described in "Publication of Vulnerability Disclosure Policy" in IXIT 2-UserInfo is possible without meeting criteria such as user account, i.e. whether anybody can access the documentation.  \nNOTE: A website of the manufacturer is considered as appropriate.'),
#   Document(metadata={'Header 1': '5.2 TSO 5.2: Implement a means to manage reports of vulnerabilities', 'Header 2': '5.2.1 Test group 5.2-1', 'Header 3': '5.2.1.1 Test case 5.2-1-1 (conceptual)', 'Header 4': 'Assignment of verdict'}, page_content='The verdict PASS is assigned if:  \n- the publication of the vulnerability disclosure policy is available for anybody.  \nThe verdict FAIL is assigned otherwise.'),
#   Document(metadata={'Header 1': '5.2 TSO 5.2: Implement a means to manage reports of vulnerabilities', 'Header 2': '5.2.1 Test group 5.2-1', 'Header 3': '5.2.1.2 Test case 5.2-1-2 (functional)', 'Header 4': 'Test purpose'}, page_content='The purpose of this test case is the functional assessment of the publication of the vulnerability disclosure policy.'),
#   Document(metadata={'Header 1': '5.2 TSO 5.2: Implement a means to manage reports of vulnerabilities', 'Header 2': '5.2.1 Test group 5.2-1', 'Header 3': '5.2.1.2 Test case 5.2-1-2 (functional)', 'Header 4': 'Test units'}, page_content='a) The TL **shall** functionally check whether the vulnerability disclosure policy is publicly accessible as described in "Publication of Vulnerability Disclosure Policy" in IXIT 2-UserInfo.  \nb) The TL **shall** functionally check whether the policy contains:  \n- contact information; and\n- information on timelines regarding acknowledgement of receipt and status updates.  \nNOTE: Information on timelines provides flexibility to describe time values (e.g. "7 days", "quickly", etc.).Further, it also allows to describe whether or how a timeline is created in the case of a reported vulnerability.'),
#   Document(metadata={'Header 1': '5.2 TSO 5.2: Implement a means to manage reports of vulnerabilities', 'Header 2': '5.2.1 Test group 5.2-1', 'Header 3': '5.2.1.2 Test case 5.2-1-2 (functional)', 'Header 4': 'Assignment of verdict'}, page_content='The verdict PASS is assigned if:  \n- the vulnerability disclosure policy is publicly accessible; and\n- the vulnerability disclosure policy contains contact information and information on timelines regarding acknowledgement of receipt and status updates.  \nThe verdict FAIL is assigned otherwise.'),
#   Document(metadata={'Header 1': '5.2 TSO 5.2: Implement a means to manage reports of vulnerabilities', 'Header 2': '5.2.2 Test Group 5.2-2', 'Header 3': '5.2.2.0 Test Group Objective'}, page_content='The test group addresses the provision 5.2-2.'),
#   Document(metadata={'Header 1': '5.2 TSO 5.2: Implement a means to manage reports of vulnerabilities', 'Header 2': '5.2.2 Test Group 5.2-2', 'Header 3': '5.2.2.1 Test case 5.2-2-1 (conceptual)', 'Header 4': 'Test purpose'}, page_content='The purpose of this test case is the conceptual assessment of the manner in which vulnerabilities are acted on a) and the confirmation that the preconditions for the implementation are ensured b).'),
#   Document(metadata={'Header 1': '5.2 TSO 5.2: Implement a means to manage reports of vulnerabilities', 'Header 2': '5.2.2 Test Group 5.2-2', 'Header 3': '5.2.2.1 Test case 5.2-2-1 (conceptual)', 'Header 4': 'Test units'}, page_content='a) The TL **shall** assess whether the "Action" and the "Time Frame" of each disclosed vulnerability in IXIT 3-VulnTypes facilitate that vulnerabilities are acted on in a timely manner under consideration of the vulnerability disclosure policy according to "Publication of Vulnerability Disclosure Policy" in IXIT 2-UserInfo.  \nNOTE 1: The consideration of severity and criticality of the addressed vulnerabilities and the kind of vulnerability\n(e.g. firmware, hardware or software) is helpful.  \nNOTE 2: The amount of collaboration between the involved entities, the number of process steps and clearly defined responsibilities are important indicators for a timely deployment.  \nNOTE 3: In the case that a third party is involved (e.g. a software library vendor) the documentation of the point of contacts and defined procedures for the collaboration are indicators for a timely deployment.  \nNOTE 4: The comparison with the time frame for acting on vulnerabilities of similar types of IoT products is helpful.  \nb) The TL **shall** check whether "Confirmation of Vulnerability Actions" in IXIT 4-Conf states a confirmation.'),
#   Document(metadata={'Header 1': '5.2 TSO 5.2: Implement a means to manage reports of vulnerabilities', 'Header 2': '5.2.2 Test Group 5.2-2', 'Header 3': '5.2.2.1 Test case 5.2-2-1 (conceptual)', 'Header 4': 'Assignment of verdict'}, page_content='Assignment of verdict The verdict PASS is assigned if:  \n- there is no indication that any described kind of vulnerability is not acted on timely; and\n- a confirmation for the implementation is given.  \nThe verdict FAIL is assigned otherwise.'),
#   Document(metadata={'Header 1': '5.2 TSO 5.2: Implement a means to manage reports of vulnerabilities', 'Header 2': '5.2.3 Test Group 5.2-3', 'Header 3': '5.2.3.0 Test group objective'}, page_content='The test group addresses the provision 5.2-3.'),
#   Document(metadata={'Header 1': '5.2 TSO 5.2: Implement a means to manage reports of vulnerabilities', 'Header 2': '5.2.3 Test Group 5.2-3', 'Header 3': '5.2.3.1 Test case 5.2-3-1 (conceptual)', 'Header 4': 'Test purpose'}, page_content='The purpose of this test case is the conceptual assessment of continuous monitoring, identifying and rectifying security vulnerabilities concerning the described procedures (a-c) and the confirmation that the preconditions for the implementation are ensured d).'),
#   Document(metadata={'Header 1': '5.2 TSO 5.2: Implement a means to manage reports of vulnerabilities', 'Header 2': '5.2.3 Test Group 5.2-3', 'Header 3': '5.2.3.1 Test case 5.2-3-1 (conceptual)', 'Header 4': 'Test units'}, page_content='a) The TL **shall** assess whether the way of continuously monitoring for security vulnerabilities documented in IXIT 5-VulnMon is suited to systematically gather information about security vulnerabilities that potentially can affect the DUT.  \nb) The TL **shall** assess whether the way of identifying security vulnerabilities documented in IXIT 5-VulnMon is suited to determine if and how a security vulnerability can affect the DUT.  \nc) The TL **shall** assess whether the way of rectifying security vulnerabilities documented in IXIT 5-VulnMon is suited to address and mitigate the susceptibility of a DUT against a security vulnerability.  \nd) The TL **shall** check whether "Confirmation of Vulnerability Monitoring" in IXIT 4-Conf states a confirmation.'),
#   Document(metadata={'Header 1': '5.2 TSO 5.2: Implement a means to manage reports of vulnerabilities', 'Header 2': '5.2.3 Test Group 5.2-3', 'Header 3': '5.2.3.1 Test case 5.2-3-1 (conceptual)', 'Header 4': 'Assignment of verdict'}, page_content='The verdict PASS is assigned if:  \n- the described way is suited for continuously monitoring for security vulnerabilities; and\n- the described way is suited for identifying security vulnerabilities; and\n- the described way is suited for rectifying security vulnerabilities; and\n- a confirmation for the implementation is given.  \nThe verdict FAIL is assigned otherwise.'),
#   Document(metadata={'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.1 Test Group 5.3-1', 'Header 3': '5.3.1.0 Test Group Objective'}, page_content='The test group addresses the provision 5.3-1.  \nThis test group handles the updatability of each software components except software updates are beyond practicability or absent for a security reason. According to ETSI TS 103 645 [1]/ETSI EN 303 645 [2] "securely updateable" means that there are adequate measures to prevent an attacker misusing the update mechanism.  \nNOTE: Any discovery of software components in the DUT is out of scope of this test group.'),
#   Document(metadata={'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.1 Test Group 5.3-1', 'Header 3': '5.3.1.0 Test Group Objective', 'Header 4': 'Test purpose'}, page_content='The purpose of this test case is the conceptual assessment of the updatability of software components concerning the absence of software updates a) and the update mechanisms b).'),
#   Document(metadata={'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.1 Test Group 5.3-1', 'Header 3': '5.3.1.0 Test Group Objective', 'Header 4': 'Test units'}, page_content='a) For each software component in IXIT 6-SoftComp with an empty list in "Update Mechanism", the TL **shall**\nassess whether the implementation of software updates is beyond practicability or for a security reason as described in the justification for the absence of software updates.  \nEXAMPLE 1: An IoT device can contain separate microcontrollers from the main system which are only internally addressable. Those microcontrollers typically act as an internal service provider (e.g. temperature controller of a smart wine rack) sometimes without update functionality. A software update for those components can be beyond practicability for the DUT.  \nEXAMPLE 2: For some implementations, the security concept for the DUT can require that a component is not changeable (e.g. software which is part of the trust chain of the bootloader). Therefore the component is not updateable for superordinate security reasons.  \nb) The TL **shall** apply all test units as specified in the Test case 5.3-2-1 to every referenced "Update Mechanism" in IXIT 6-SoftComp.'),
#   Document(metadata={'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.1 Test Group 5.3-1', 'Header 3': '5.3.1.0 Test Group Objective', 'Header 4': 'Assignment of verdict'}, page_content='The verdict PASS is assigned if:  \n- for all software components without the ability for software updates, a software update is not possible for practicability reasons or security reasons; and\n- no update mechanism can be misused by an attacker.  \nThe verdict FAIL is assigned otherwise.'),
#   Document(metadata={'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.1 Test Group 5.3-1', 'Header 3': '5.3.1.2 Test case 5.3-1-2 (functional)', 'Header 4': 'Test purpose'}, page_content='The purpose of this test case is the functional assessment of the effectiveness of the update mechanisms to avoid misuse.'),
#   Document(metadata={'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': 'Test Units'}, page_content='a) The TL **shall** apply all test units as specified in the Test case 5.3-2-2 to every referenced "Update Mechanism" in IXIT 6-SoftComp.'),
#   Document(metadata={'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': 'Test Units', 'Header 4': 'Assignment of verdict'}, page_content='The verdict PASS is assigned if:  \n- there is no indication that a misuse of any update mechanism is possible.  \nThe verdict FAIL is assigned otherwise.'),
#   Document(metadata={'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.2 Test group 5.3-2', 'Header 3': '5.3.2.0 Test group objective'}, page_content='The test group addresses the provision 5.3-2.  \nThis test group examines that at least one update mechanism for the secure installation of software updates exists.'),
#   Document(metadata={'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.2 Test group 5.3-2', 'Header 3': '5.3.2.1 Test case 5.3-2-1 (conceptual)', 'Header 4': 'Test purpose'}, page_content='The purpose of this test case is the conceptual assessment of the update installation mechanism concerning adequate measures to prevent an attacker misusing the update installation on the DUT.'),
#   Document(metadata={'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.2 Test group 5.3-2', 'Header 3': '5.3.2.1 Test case 5.3-2-1 (conceptual)', 'Header 4': 'Test units'}, page_content='a) For each update mechanism in IXIT 7-UpdMech, the TL **shall** assess whether the design of the update mechanism prevents misuse from an attacker according to the "Security Guarantees", the corresponding\n"Description", "Cryptographic Details" and "Initiation and Interaction".  \nNOTE: The consideration of the baseline attacker model described in clause D.2 is helpful for the examination.  \nEXAMPLE: A misuse can be the installation of an old software update to downgrade the security capabilities of the DUT or the injection of malware by manipulating a valid update.'),
#   Document(metadata={'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.2 Test group 5.3-2', 'Header 3': '5.3.2.1 Test case 5.3-2-1 (conceptual)', 'Header 4': 'Assignment of verdict'}, page_content='The verdict PASS is assigned if:  \n- one update mechanism of the DUT cannot be misused by an attacker.  \nThe verdict FAIL is assigned otherwise.'),
#   Document(metadata={'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.2 Test group 5.3-2', 'Header 3': '5.3.2.2 Test case 5.3-2-2 (functional)', 'Header 4': 'Test purpose'}, page_content='The purpose of this test case is the functional assessment of the effectiveness of the update mechanism to avoid misuse. Test units a) For each update mechanism in IXIT 7-UpdMech, the TL **shall** devise functional attacks to misuse the update mechanism based on the "Description".  \nEXAMPLE 1: If applicable try a Man-In-The-Middle attack (MITM) between the DUT and the update server.  \nNOTE 1: An attack can be trying to resume the sequence of update steps after some failure of a specific update step, installing an older firmware version that contains security vulnerabilities, or changing one byte in a signed firmware to check that it is rejected.  \nNOTE 2: There are multiple ways to perform an indication based security analysis even if no update is available during the assessment, e.g. verify a file based update mechanism on the base of old update packages.  \nb) The TL **shall** attempt to misuse each update mechanism on the base of the devised adverse actions and assess whether the design of the mechanism (see "Description", the "Cryptographic Details" and "Initiation and Interaction") effectively prevents the misuse of software updates as described in the "Security Guarantees".  \nEXAMPLE 2: If a file based update mechanism uses signature verifications, providing a manipulated update package to the DUT can be helpful to collect indications.'),
#   Document(metadata={'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.2 Test group 5.3-2', 'Header 3': '5.3.2.2 Test case 5.3-2-2 (functional)', 'Header 4': 'Assignment of verdict'}, page_content='The verdict PASS is assigned if:  \n- there is no indication that a misuse of one update mechanism of the DUT is possible.  \nThe verdict FAIL is assigned otherwise.'),
#   Document(metadata={'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.3 Test group 5.3-3', 'Header 3': '5.3.3.0 Test group objective'}, page_content='The test group addresses the provision 5.3-3.  \nAccording to ETSI TS 103 645 [1]/ETSI EN 303 645 [2] in terms of this test group an update that is simple to apply will be automatically applied, or initiated using an associated service (such as a mobile application) or via a web interface on the device. However, this does not exclude alternative solutions.  \nThe focus of the provision is on triggering the update from the user perspective and verifying whether the user is provided with the ability to update all software components in a simple manner. This case is given if each software component is updatable with at least one simple update mechanism.'),
#   Document(metadata={'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.3 Test group 5.3-3', 'Header 3': '5.3.3.1 Test case 5.3-3-1 (conceptual)', 'Header 4': 'Test purpose'}, page_content='The purpose of this test case is the conceptual assessment of the update mechanisms concerning simplicity for the user to apply an update.'),
#   Document(metadata={'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.3 Test group 5.3-3', 'Header 3': '5.3.3.1 Test case 5.3-3-1 (conceptual)', 'Header 4': 'Test units'}, page_content='a) For each software component in IXIT 6-SoftComp, the TL **shall** assess whether at least one "Update Mechanism" is described, which is simple for the user to apply according to "Initiation and Interaction" in IXIT 7-UpdMech based on the following factors:  \n- the software update is automatically applied without requiring any user interaction; or\n- the software update is initiated via an associated service; or\n- the software update is initiated via a web interface on the device; or\n- the software update uses a comparable approach which is applicable for the user with limited technical knowledge (see clause D.3).'),
#   Document(metadata={'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.3 Test group 5.3-3', 'Header 3': '5.3.3.1 Test case 5.3-3-1 (conceptual)', 'Header 4': 'Assignment of verdict'}, page_content='The verdict PASS is assigned if:  \n- each software component is covered by at least one update mechanism, which is simple for the user to apply.  \nThe verdict FAIL is assigned otherwise.'),
#   Document(metadata={'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.4 Test Group 5.3-4', 'Header 3': '5.3.4.0 Test Group Objective'}, page_content='The test group addresses the provision 5.3-4.  \nAutomatic mechanisms for software updates consider the checking for update availability and performing the update.  \nThe focus of the provision is on triggering the update from the user perspective and verifying whether the user is provided with the ability to update all software components automatically. This case is given if each software component is updatable with at least one automatic update mechanism.'),
#   Document(metadata={'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.4 Test Group 5.3-4', 'Header 3': '5.3.4.1 Test case 5.3-4-1 (conceptual)', 'Header 4': 'Test purpose'}, page_content='The purpose of this test case is the conceptual assessment of the update mechanisms concerning automatic mechanisms.'),
#   Document(metadata={'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.4 Test Group 5.3-4', 'Header 3': '5.3.4.1 Test case 5.3-4-1 (conceptual)', 'Header 4': 'Test units'}, page_content='a) For each software component in IXIT 6-SoftComp, the TL **shall** assess whether at least one "Update Mechanism" is described in IXIT 7-UpdMech, that allows:  \n- the performance of updates without requiring any user interaction according to "Initiation and Interaction"; and\n- the "Update Checking" without requiring any user interaction.  \nb) For each software component in IXIT 6-SoftComp covered by an "Update Mechanism" in IXIT 7-UpdMech with the capability to configure the automation according to "Configuration", the TL **shall** check whether at least one of the automatic mechanisms is enabled by default.'),
#   Document(metadata={'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.4 Test Group 5.3-4', 'Header 3': '5.3.4.1 Test case 5.3-4-1 (conceptual)', 'Header 4': 'Assignment of verdict'}, page_content='The verdict PASS is assigned if:  \n- each software component is covered by at least one update mechanism that does not require any user interaction for performing an update and for checking the availability of an update; and\n- for each software component covered by a configurable update mechanism at least one of the automatic mechanisms is enabled by default.  \nThe verdict FAIL is assigned otherwise.'),
#   Document(metadata={'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.5 Test Group 5.3-5', 'Header 3': '5.3.5.0 Test Group Objective'}, page_content='The test group addresses the provision 5.3-5.  \nThe focus of the provision is on the ability to check for security updates for the software of the DUT. This case is given if each software component is updatable with at least one update mechanism checking for security updates after initialization and periodically.'),
#   Document(metadata={'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.5 Test Group 5.3-5', 'Header 3': '5.3.5.1 Test case 5.3-5-1 (conceptual)', 'Header 4': 'Test purpose'}, page_content='The purpose of this test case is the conceptual assessment of the update mechanisms concerning the checks for available security updates.'),
#   Document(metadata={'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.5 Test Group 5.3-5', 'Header 3': '5.3.5.1 Test case 5.3-5-1 (conceptual)', 'Header 4': 'Test units'}, page_content='a) For each software component in IXIT 6-SoftComp, the TL **shall** assess whether at least one "Update Mechanism" is described in IXIT 7-UpdMech, that checks the availability of security updates according to the schedule for querying for security updates in "Update Checking":  \n- after initialization of the DUT; and  \n- periodically.  \nNOTE: A daily security update check at a randomized time can be appropriate depending on the type of device.'),
#   Document(metadata={'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.5 Test Group 5.3-5', 'Header 3': '5.3.5.1 Test case 5.3-5-1 (conceptual)', 'Header 4': 'Assignment of verdict'}, page_content='The verdict PASS is assigned if every software component is covered by at least one update mechanism, where:  \n- the checking of the availability of software updates is triggered by the DUT itself; and\n- the availability of software updates is checked after initialization of the DUT; and\n- the availability of software updates is checked periodically.  \nThe verdict FAIL is assigned otherwise.'),
#   Document(metadata={'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.6 Test Group 5.3-6', 'Header 3': '5.3.6.0 Test Group Objective'}, page_content='The test group addresses the provision 5.3-6.  \nNOTE 1: The entry "Initiation and Interaction" in IXIT 7-UpdMech indicates whether it is an automatic update mechanism in combination with the test units in Test group 5.3-4.  \nNOTE 2: The entry "User Notification" in IXIT 7-UpdMech indicates whether it supports update notifications.  \nNOTE 3: The provision addresses two different functionalities ("automatic updates" und "update notification") of an update mechanism. Furthermore, the provision is fulfilled for an update mechanism if one of these functionalities or both cover the requirements of the provision.'),
#   Document(metadata={'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.6 Test Group 5.3-6', 'Header 3': '5.3.6.1 Test case 5.3-6-1 (conceptual)', 'Header 4': 'Test purpose'}, page_content='The purpose of this test case is the conceptual assessment of the configuration of automatic updates (a-c) and update notifications (d-e).'),
# ...
#   Document(metadata={'Header 1': '5.13 Tso 5.13: Validate Input Data', 'Header 2': '5.13.1 Test Group 5.13-1', 'Header 3': '5.13.1.2 Test Case 5.13-1-2 (Functional)', 'Header 4': 'Assignment of verdict'}, page_content='The verdict PASS is assigned if:  \n- there is no indication that any data input validation does not protect against the processing of unexpected data input; and\n- every discovered user interface is documented in the IXIT; and\n- every discovered remotely accessible API is documented in the IXIT.  \nThe verdict FAIL is assigned otherwise.'),
#   Document(metadata={'Header 1': '5.14 Tso 6: Data Protection For Consumer Iot', 'Header 2': '5.14.1 Test group 6-1', 'Header 3': '5.14.1.0 Test group objective'}, page_content='The test group addresses the provision 6-1.'),
#   Document(metadata={'Header 1': '5.14 Tso 6: Data Protection For Consumer Iot', 'Header 2': '5.14.1 Test group 6-1', 'Header 3': '5.14.1.1 Test case 6-1-1 (conceptual)', 'Header 4': 'Test purpose'}, page_content='The purpose of this test case is the conceptual assessment of the user information about the processing of personal data.'),
#   Document(metadata={'Header 1': '5.14 Tso 6: Data Protection For Consumer Iot', 'Header 2': '5.14.1 Test group 6-1', 'Header 3': '5.14.1.1 Test case 6-1-1 (conceptual)', 'Header 4': 'Test units'}, page_content='a) The TL **shall** assess whether the "Documentation of Personal Data" in IXIT 2-UserInfo is suitable for the consumer to obtain the information about processing personal data.'),
#   Document(metadata={'Header 1': '5.14 Tso 6: Data Protection For Consumer Iot', 'Header 2': '5.14.1 Test group 6-1', 'Header 3': '5.14.1.1 Test case 6-1-1 (conceptual)', 'Header 4': 'Assignment of verdict'}, page_content='The verdict PASS is assigned if:  \n- the information about processing personal data is suitably provided to the consumer.  \nThe verdict FAIL is assigned otherwise.'),
#   Document(metadata={'Header 1': '5.14 Tso 6: Data Protection For Consumer Iot', 'Header 2': '5.14.1 Test group 6-1', 'Header 3': '5.14.1.2 Test case 6-1-2 (functional)', 'Header 4': 'Test purpose'}, page_content='The purpose of this test case is the functional assessment of the user information about the processing of personal data.'),
#   Document(metadata={'Header 1': '5.14 Tso 6: Data Protection For Consumer Iot', 'Header 2': '5.14.1 Test group 6-1', 'Header 3': '5.14.1.2 Test case 6-1-2 (functional)', 'Header 4': 'Test units'}, page_content='a) The TL **shall** functionally assess whether the provided information about processing personal data (obtained information) is consistent to the description in "Documentation of Personal Data" in IXIT 2-UserInfo.  \nb) The TL **shall** functionally assess whether the obtained information about processing personal data accessing the "Documentation of Personal Data" in IXIT 2-UserInfo match their description in "Processing Activities" in IXIT 21-PersData.  \nc) The TL **shall** functionally assess whether the obtained information describes what personal data is processed in a way understandable for a user with limited technical knowledge (see clause D.3).  \nd) The TL **shall** functionally assess whether the obtained information describe how personal data is being used, by whom, and for what purposes in a way understandable for a user with limited technical knowledge (see clause D.3).'),
#   Document(metadata={'Header 1': '5.14 Tso 6: Data Protection For Consumer Iot', 'Header 2': '5.14.1 Test group 6-1', 'Header 3': '5.14.1.2 Test case 6-1-2 (functional)', 'Header 4': 'Assignment of verdict'}, page_content='The verdict PASS is assigned if:  \n- the information about processing personal data can be obtained as described; and\n- the obtained information about processing personal data match their description; and\n- the personal data being processed is clearly and transparently described; and\n- it is clearly and transparently described how personal data is being used, by whom, and for what purposes.  \nThe verdict FAIL is assigned otherwise.'),
#   Document(metadata={'Header 1': '5.14 Tso 6: Data Protection For Consumer Iot', 'Header 2': '5.14.2 Test Group 6-2', 'Header 3': '5.14.2.0 Test Group Objective'}, page_content='The test group addresses the provision 6-2.  \nAccording to ETSI TS 103 645 [1]/ETSI EN 303 645 [2], obtaining consent "in a valid way" normally involves giving consumers a free, obvious and explicit opt-in choice of whether their personal data is used for a specified purpose.'),
#   Document(metadata={'Header 1': '5.14 Tso 6: Data Protection For Consumer Iot', 'Header 2': '5.14.2 Test Group 6-2', 'Header 3': '5.14.2.1 Test case 6-2-1 (conceptual)', 'Header 4': 'Test purpose'}, page_content="The purpose of this test case is the conceptual assessment of the consumers' consent for the processing of personal data."),
#   Document(metadata={'Header 1': '5.14 Tso 6: Data Protection For Consumer Iot', 'Header 2': '5.14.2 Test Group 6-2', 'Header 3': '5.14.2.1 Test case 6-2-1 (conceptual)', 'Header 4': 'Test units'}, page_content='a) For each personal data in IXIT 21-PersData that is processed on the basis of consumers\' consent according to\n"Obtaining Consent", the TL **shall** assess whether the opt-in choice:  \n- is given freely; and\n- is given obviously; and\n- is given explicitly according to the description of "Obtaining Consent".'),
#   Document(metadata={'Header 1': '5.14 Tso 6: Data Protection For Consumer Iot', 'Header 2': '5.14.2 Test Group 6-2', 'Header 3': '5.14.2.1 Test case 6-2-1 (conceptual)', 'Header 4': 'Assignment of verdict'}, page_content="The verdict PASS is assigned if for each category of personal data that is processed on the basis of consumers' consent:  \n- it is described how to express consent (opt-in choice) to the processing of personal data for specific purposes; and\n- the opt-in choice is given freely, obviously and explicitly.  \nThe verdict FAIL is assigned otherwise."),
#   Document(metadata={'Header 1': '5.14 Tso 6: Data Protection For Consumer Iot', 'Header 2': '5.14.2 Test Group 6-2', 'Header 3': '5.14.2.2 Test case 6-2-2 (functional)', 'Header 4': 'Test purpose'}, page_content="The purpose of this test case is the functional assessment of the consumers' consent for the processing of personal data."),
#   Document(metadata={'Header 1': '5.14 Tso 6: Data Protection For Consumer Iot', 'Header 2': '5.14.2 Test Group 6-2', 'Header 3': '5.14.2.2 Test case 6-2-2 (functional)', 'Header 4': 'Test units'}, page_content='a) For each personal data in IXIT 21-PersData that is processed on the basis of consumers\' consent according to "Obtaining Consent", the TL **shall** functionally assess whether consumers\' consent to processing personal data is obtained as described in the IXIT.'),
#   Document(metadata={'Header 1': '5.14 Tso 6: Data Protection For Consumer Iot', 'Header 2': '5.14.2 Test Group 6-2', 'Header 3': '5.14.2.2 Test case 6-2-2 (functional)', 'Header 4': 'Assignment of verdict'}, page_content="The verdict PASS is assigned if for each category of personal data that is processed on the basis of consumers' consent:  \n- the way of obtaining consumers' consent matches the description.  \nThe verdict FAIL is assigned otherwise."),
#   Document(metadata={'Header 1': '5.14 Tso 6: Data Protection For Consumer Iot', 'Header 2': '5.14.3 Test group 6-3', 'Header 3': '5.14.3.0 Test Group Objective'}, page_content='The test group addresses the provision 6-3.  \nAccording to ETSI TS 103 645 [1]/ETSI EN 303 645 [2], withdrawing consent at any time normally involves configuring IoT device and service functionality appropriately.'),
#   Document(metadata={'Header 1': '5.14 Tso 6: Data Protection For Consumer Iot', 'Header 2': '5.14.3 Test group 6-3', 'Header 3': '5.14.3.1 Test case 6-3-1 (conceptual)', 'Header 4': 'Test purpose'}, page_content="The purpose of this test case is the conceptual assessment of withdrawing consumers' consent for the processing of personal data."),
#   Document(metadata={'Header 1': '5.14 Tso 6: Data Protection For Consumer Iot', 'Header 2': '5.14.3 Test group 6-3', 'Header 3': '5.14.3.1 Test case 6-3-1 (conceptual)', 'Header 4': 'Test units'}, page_content='a) For each personal data in IXIT 21-PersData that is processed on the basis of consumers\' consent according to "Obtaining Consent", the TL **shall** assess whether the information on "Withdrawing Consent" describes how to withdraw consent to the processing of personal data at any time by configuring IoT device and service functionality appropriately.'),
#   Document(metadata={'Header 1': '5.14 Tso 6: Data Protection For Consumer Iot', 'Header 2': '5.14.3 Test group 6-3', 'Header 3': '5.14.3.1 Test case 6-3-1 (conceptual)', 'Header 4': 'Assignment of verdict'}, page_content="The verdict PASS is assigned if for each category of personal data that is processed on the basis of consumers' consent:  \n- it is described how to withdraw consent to the processing of personal data at any time.  \nThe verdict FAIL is assigned otherwise."),
#   Document(metadata={'Header 1': '5.14 Tso 6: Data Protection For Consumer Iot', 'Header 2': '5.14.3.2 Test Case 6-3-2 (Functional)', 'Header 4': 'Test Purpose'}, page_content="The purpose of this test case is the functional assessment of withdrawing consumers' consent for the processing of personal data."),
#   Document(metadata={'Header 1': '5.14 Tso 6: Data Protection For Consumer Iot', 'Header 2': '5.14.3.2 Test Case 6-3-2 (Functional)', 'Header 4': 'Test Units'}, page_content='a) For each personal data in IXIT 21-PersData that is processed on the basis of consumers\' consent according to "Obtaining Consent", the TL **shall** functionally assess whether consumers\' consent to processing personal data can be withdrawn as described in "Withdrawing Consent".'),
#   Document(metadata={'Header 1': '5.14 Tso 6: Data Protection For Consumer Iot', 'Header 2': '5.14.3.2 Test Case 6-3-2 (Functional)', 'Header 4': 'Assignment of verdict'}, page_content="The verdict PASS is assigned if for each category of personal data that is processed on the basis of consumers' consent:  \n- the way of withdrawing consumers' consent matches the description.  \nThe verdict FAIL is assigned otherwise."),
#   Document(metadata={'Header 1': '5.14 Tso 6: Data Protection For Consumer Iot', 'Header 2': '5.14.4 Test group 6-4', 'Header 3': '5.14.4.0 Test group objective'}, page_content='The test group addresses the provision 6-4.'),
#   Document(metadata={'Header 1': '5.14 Tso 6: Data Protection For Consumer Iot', 'Header 2': '5.14.4 Test group 6-4', 'Header 3': '5.14.4.1 Test case 6-4-1 (conceptual)', 'Header 4': 'Test purpose'}, page_content='The purpose of this test case is the conceptual assessment of the processing of telemetry data.'),
#   Document(metadata={'Header 1': '5.14 Tso 6: Data Protection For Consumer Iot', 'Header 2': '5.14.4 Test group 6-4', 'Header 3': '5.14.4.1 Test case 6-4-1 (conceptual)', 'Header 4': 'Test units'}, page_content='a) The TL **shall** assess whether the personal data in IXIT 21-PersData that are referenced in "Personal Data" in IXIT 24-TelData is necessary for the intended functionality as described in the "Purpose" of collecting the data.  \nNOTE: Telemetry data are considered to be necessary for the intended functionality if and only if they are needed for achieving the processing purposes.'),
#   Document(metadata={'Header 1': '5.14 Tso 6: Data Protection For Consumer Iot', 'Header 2': '5.14.4 Test group 6-4', 'Header 3': '5.14.4.1 Test case 6-4-1 (conceptual)', 'Header 4': 'Assignment of verdict'}, page_content='The verdict PASS is assigned if for each telemetry data:  \n- their processing is necessary for the intended functionality.  \nThe verdict FAIL is assigned otherwise.'),
#   Document(metadata={'Header 1': '5.14 Tso 6: Data Protection For Consumer Iot', 'Header 2': '5.14.5 Test group 6-5', 'Header 3': '5.14.5.0 Test group objective'}, page_content='The test group addresses the provision 6-5.'),
#   Document(metadata={'Header 1': '5.14 Tso 6: Data Protection For Consumer Iot', 'Header 2': '5.14.5 Test group 6-5', 'Header 3': '5.14.5.1 Test case 6-5-1 (conceptual)', 'Header 4': 'Test purpose'}, page_content='The purpose of this test case is the conceptual assessment of the user information about the processing of telemetry data.'),
#   Document(metadata={'Header 1': '5.14 Tso 6: Data Protection For Consumer Iot', 'Header 2': '5.14.5 Test group 6-5', 'Header 3': '5.14.5.1 Test case 6-5-1 (conceptual)', 'Header 4': 'Test units'}, page_content='a) The TL **shall** assess whether the "Documentation of Telemetry Data" in IXIT 2-UserInfo is suitable for the consumer to obtain the information about processing telemetry data.'),
#   Document(metadata={'Header 1': '5.14 Tso 6: Data Protection For Consumer Iot', 'Header 2': '5.14.5 Test group 6-5', 'Header 3': '5.14.5.1 Test case 6-5-1 (conceptual)', 'Header 4': 'Assignment of verdict'}, page_content='The verdict PASS is assigned if:  \n- the information about processing telemetry data is suitably provided to the consumer.  \nThe verdict FAIL is assigned otherwise.'),
#   Document(metadata={'Header 1': '5.14 Tso 6: Data Protection For Consumer Iot', 'Header 2': '5.14.5.2 Test Case 6-5-2 (Functional)', 'Header 4': 'Test Purpose'}, page_content='The purpose of this test case is the functional assessment of user the information about the processing of telemetry data.'),
#   Document(metadata={'Header 1': '5.14 Tso 6: Data Protection For Consumer Iot', 'Header 2': '5.14.5.2 Test Case 6-5-2 (Functional)', 'Header 4': 'Test units'}, page_content='a) The TL **shall** functionally assess whether the provided information about processing telemetry data (obtained information) is consistent with the description in "Documentation of Telemetry Data" in IXIT 2-UserInfo.  \nb) The TL **shall** functionally assess whether the obtained information about processing telemetry data accessing the "Documentation of Telemetry Data" in IXIT 2-UserInfo match their "Purpose" described in IXIT 24-TelData.  \nc) The TL **shall** functionally check whether the obtained information describes what telemetry data is collected.  \nd) The TL **shall** functionally check whether the obtained information describes how telemetry data is being used, by whom, and for what purposes.'),
#   Document(metadata={'Header 1': '5.14 Tso 6: Data Protection For Consumer Iot', 'Header 2': '5.14.5.2 Test Case 6-5-2 (Functional)', 'Header 4': 'Assignment of verdict'}, page_content='The verdict PASS is assigned if:  \n- the information about processing telemetry data can be obtained as described; and\n- the obtained information about processing telemetry data match their description; and\n- the telemetry data being collected is described; and\n- it is completely described how telemetry data is being used, by whom, and for what purposes.  \nThe verdict FAIL is assigned otherwise.')])

# %% [markdown]
# ### UnstructuredMarkdownLoader with element (for testing)

# %%
import os

import dotenv
from langchain_community.document_loaders import UnstructuredMarkdownLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

dotenv.load_dotenv()
ROOT_PATH = os.path.expanduser(os.getenv("ROOT_PATH"))

document_root_path = os.path.join(ROOT_PATH, "docs")

# database does not exist, create it
loader = UnstructuredMarkdownLoader(
    os.path.join(document_root_path, "ts_103701_only_test_scenario.md"), mode="elements"
)
doc = loader.load()

text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
splits = text_splitter.split_documents(doc)
splits
# Out:
# [Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 0, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'Title', 'element_id': '3eb24cc2acf37c1b0a9f4fbda123aca1'}, page_content='5.0 TSO 4: Reporting implementation'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 1, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '3eb24cc2acf37c1b0a9f4fbda123aca1', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'Title', 'element_id': 'c36d324d896d5ddb4a4c1b32429f4450'}, page_content='5.0.1 Test group 4-1'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 2, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': 'c36d324d896d5ddb4a4c1b32429f4450', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'Title', 'element_id': 'f5de173a47e4c390fbce0b22ebe98bce'}, page_content='5.0.1.0 Test group objective'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': 'f5de173a47e4c390fbce0b22ebe98bce', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': '2bfddf2d1bde0e1a059b5e927761f7b7'}, page_content='The test group addresses the provision 4-1.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 2, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': 'c36d324d896d5ddb4a4c1b32429f4450', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'Title', 'element_id': '85c33f82b3dae1dcd6171835b62f75dd'}, page_content='5.0.1.1 Test Case 4-1-1 (Conceptual)'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 3, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '85c33f82b3dae1dcd6171835b62f75dd', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'Title', 'element_id': '3d43e57c1c3c09a5a52b493d95d87058'}, page_content='Test purpose'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '3d43e57c1c3c09a5a52b493d95d87058', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': '8fb8cb4812ffc04de56b5cd006599528'}, page_content='The purpose of this test case is the conceptual assessment of the justifications for recommendations that are considered to be not applicable for or not fulfilled by the DUT.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 3, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '85c33f82b3dae1dcd6171835b62f75dd', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'Title', 'element_id': '1b7a94f5deb95ed586876d540595d2a1'}, page_content='Test units'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'emphasized_text_contents': ['shall'], 'emphasized_text_tags': ['b'], 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '1b7a94f5deb95ed586876d540595d2a1', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': '5ed30e34ceee488d0022ba22980df3c9'}, page_content='a) The TL shall check whether a justification is given in the ICS for each recommendation that is considered to be not applicable for or not fulfilled by the DUT.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 3, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '85c33f82b3dae1dcd6171835b62f75dd', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'Title', 'element_id': 'cf28c48cbb2948a843f53a0c3873b3c5'}, page_content='Assignment of verdict'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': 'cf28c48cbb2948a843f53a0c3873b3c5', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': '3c2aae7f1987bd809a6693cdbea08e53'}, page_content='The verdict PASS is assigned if:'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 1, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': 'cf28c48cbb2948a843f53a0c3873b3c5', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'ListItem', 'element_id': '324ed1d82a5eadf6a069b5ca87c957de'}, page_content='a justification is given for every recommendation that is considered to be not applicable for the DUT; and'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 1, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': 'cf28c48cbb2948a843f53a0c3873b3c5', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'ListItem', 'element_id': '6813df618eafe94d3052db559915e62f'}, page_content='a justification is given for every recommendation that is considered to be not fulfilled by the DUT.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': 'cf28c48cbb2948a843f53a0c3873b3c5', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': '6b78e2e0b7732e29439e2334fd5d000f'}, page_content='The verdict FAIL is assigned otherwise.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 0, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'Title', 'element_id': 'c3476ae1b58aa6c20b459888a501930e'}, page_content='5.1 Tso 5.1: No Universal Default Passwords'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 1, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': 'c3476ae1b58aa6c20b459888a501930e', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'Title', 'element_id': '0af4bd600b36eed245b01a13eb9af5d3'}, page_content='5.1.1 Test group 5.1-1'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 2, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '0af4bd600b36eed245b01a13eb9af5d3', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'Title', 'element_id': '60baf0ac42d0b9f8c1e1cea0122ee7ba'}, page_content='5.1.1.0 Test group objective'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '60baf0ac42d0b9f8c1e1cea0122ee7ba', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': 'd8f54777531481d9da736125edb283be'}, page_content='The test group addresses the provision 5.1-1.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '60baf0ac42d0b9f8c1e1cea0122ee7ba', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': '0f7e4cf49c6c5306a85f5f942561b588'}, page_content='This test group addresses all states of the DUT with the exception of factory default.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 2, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '0af4bd600b36eed245b01a13eb9af5d3', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'Title', 'element_id': 'dd07b79f6876e2035ecccaf432e668ac'}, page_content='5.1.1.1 Test case 5.1-1-1 (conceptual)'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 3, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': 'dd07b79f6876e2035ecccaf432e668ac', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'Title', 'element_id': '46f053467f07c841e3de68b4069def82'}, page_content='Test purpose'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '46f053467f07c841e3de68b4069def82', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': '62c23f5b38fb0a0e573f220517f9dfd1'}, page_content='The purpose of this test case is the conceptual assessment of the password-based authentication mechanisms.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 3, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': 'dd07b79f6876e2035ecccaf432e668ac', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'Title', 'element_id': 'ea4e60b0e888e29134b81fe4c5786ed0'}, page_content='Test units'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'emphasized_text_contents': ['shall'], 'emphasized_text_tags': ['b'], 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': 'ea4e60b0e888e29134b81fe4c5786ed0', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': '955c1e0d4cf99061acca9c97102ea8db'}, page_content='a) The TL shall assess for all password-based user authentication mechanisms in IXIT 1-AuthMech where passwords are not defined by the user according to "Authentication Factor" and used in any state other than the factory default whether the "Password Generation Mechanism" ensures that passwords are unique per device.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 3, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': 'dd07b79f6876e2035ecccaf432e668ac', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'Title', 'element_id': '7ef0a30c7153b2bfa29773212e457d5d'}, page_content='Assignment of verdict'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '7ef0a30c7153b2bfa29773212e457d5d', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': '99a0393d4c17ddd2d3f9cfbf9f0e9343'}, page_content='The verdict PASS is assigned if:'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 1, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '7ef0a30c7153b2bfa29773212e457d5d', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'ListItem', 'element_id': '4c7635260a75e0d44960009a0a4d61d5'}, page_content='each password of a password-based authentication mechanism being used in any state other than the factory default, that is not defined by the user, is unique per device.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '7ef0a30c7153b2bfa29773212e457d5d', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': '40df657aad6bf7336bf0476e37860e11'}, page_content='The verdict FAIL is assigned otherwise.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 2, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '0af4bd600b36eed245b01a13eb9af5d3', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'Title', 'element_id': 'b87b3ee504c07639b3ead371557efb13'}, page_content='5.1.1.2 Test case 5.1-1-2 (functional)'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 3, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': 'b87b3ee504c07639b3ead371557efb13', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'Title', 'element_id': '8087172b252982e274e0b9c9e4615f82'}, page_content='Test purpose'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '8087172b252982e274e0b9c9e4615f82', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': 'a82afd079263ebacb47099ee2f8daf23'}, page_content='The purpose of this test case is the functional assessment of the password-based authentication mechanisms concerning the completeness of the IXIT documentation a), the passwords defined by the user b) and the generation mechanisms c).'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 3, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': 'b87b3ee504c07639b3ead371557efb13', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'Title', 'element_id': '5edce5f4ac9c5b3588c47cb90c2819e3'}, page_content='Test units'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'emphasized_text_contents': ['shall'], 'emphasized_text_tags': ['b'], 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '5edce5f4ac9c5b3588c47cb90c2819e3', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': 'a4f6f5971d1ee4286fae87c705fc39a3'}, page_content='a) The TL shall functionally assess whether password-based authentication mechanisms that are not documented in IXIT 1-AuthMech are available via a network interface on the DUT or described in the user manual.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '5edce5f4ac9c5b3588c47cb90c2819e3', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': '82fffe364f770dd47bc769a1a6e6694b'}, page_content='EXAMPLE: Network scanning tools allow for discovery of network-based authentication mechanisms.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'emphasized_text_contents': ['shall'], 'emphasized_text_tags': ['b'], 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '5edce5f4ac9c5b3588c47cb90c2819e3', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': '9d8df514f58dd7c97b2c9682e17c5302'}, page_content='b) For each password-based user authentication mechanism in IXIT 1-AuthMech, the TL shall functionally check whether the user is required to define all passwords that are user-defined according to "Authentication Factor" before being used.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'emphasized_text_contents': ['shall'], 'emphasized_text_tags': ['b'], 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '5edce5f4ac9c5b3588c47cb90c2819e3', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': '6ca03867f44410f2578c13ee409f665c'}, page_content='c) The TL shall functionally assess whether all passwords of the DUT, that are not defined by the user according to "Authentication Factor" in IXIT 1-AuthMech and used in any state other than the factory default, do not violate the description of the "Password Generation Mechanism".'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 3, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': 'b87b3ee504c07639b3ead371557efb13', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'Title', 'element_id': 'c0d1db6fb6f817ef03592496a64121fb'}, page_content='Assignment of verdict'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': 'c0d1db6fb6f817ef03592496a64121fb', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': '44075b4ef11f2d77fabbddc7dd696450'}, page_content='The verdict PASS is assigned if:'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 1, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': 'c0d1db6fb6f817ef03592496a64121fb', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'ListItem', 'element_id': 'f4d066ae86d73ebb9d81cbe800b157d1'}, page_content='every discovered password-based authentication mechanism is documented in the IXIT; and'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 1, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': 'c0d1db6fb6f817ef03592496a64121fb', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'ListItem', 'element_id': '28a155af91e6ba4732b934877caef968'}, page_content='the user is required to define all passwords before being used, that are stated as defined by the user in the IXIT; and'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 1, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': 'c0d1db6fb6f817ef03592496a64121fb', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'ListItem', 'element_id': '50e1b6a4255a59fe9ba565bc0606c9a0'}, page_content='there is no indication that the generation of a not user-defined password of the DUT used in any state other than the factory default differs from the generation mechanism described in the IXIT.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': 'c0d1db6fb6f817ef03592496a64121fb', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': '4d7639898bace79f40efea9456e34e4c'}, page_content='The verdict FAIL is assigned otherwise.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 1, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': 'c3476ae1b58aa6c20b459888a501930e', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'Title', 'element_id': '59b3c9b6ddb30fc58aa688730ed835a7'}, page_content='5.1.2 Test Group 5.1-2'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 2, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '59b3c9b6ddb30fc58aa688730ed835a7', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'Title', 'element_id': 'c9926a2b570ee6640e84637928cab349'}, page_content='5.1.2.0 Test group objective'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': 'c9926a2b570ee6640e84637928cab349', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': '0b8c9fb35263b174b2e390932e1bed25'}, page_content='The test group addresses the provision 5.1-2.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 2, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '59b3c9b6ddb30fc58aa688730ed835a7', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'Title', 'element_id': '93bbcc216c2cd901d8339757937aadbb'}, page_content='5.1.2.1 Test case 5.1-2-1 (conceptual)'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 3, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '93bbcc216c2cd901d8339757937aadbb', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'Title', 'element_id': '6691504ff161cdb126d3dd62950d80eb'}, page_content='Test purpose'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '6691504ff161cdb126d3dd62950d80eb', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': '04cfe2540542050b07f7b3dce61b6aa8'}, page_content='The purpose of this test case is the conceptual assessment of the generation mechanisms of pre-installed passwords.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 3, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '93bbcc216c2cd901d8339757937aadbb', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'Title', 'element_id': 'fd537780925adcd93a05312c63731e02'}, page_content='Test units'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'emphasized_text_contents': ['shall'], 'emphasized_text_tags': ['b'], 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': 'fd537780925adcd93a05312c63731e02', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': 'a8e43a0044546c8ef08e28cd4108107b'}, page_content='a) The TL shall assess for each authentication mechanism in IXIT 1-AuthMech using pre-installed passwords according to "Authentication Factor", whether the generation mechanism in "Password Generation Mechanism" induces obvious regularities in the resulting passwords.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': 'fd537780925adcd93a05312c63731e02', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': 'c92f79d70b660b8ac4ba6f6d4b7bcaf7'}, page_content='NOTE 1: Incremental counters (such as "password1", "password2" and so on) can be obvious regularities.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'emphasized_text_contents': ['shall'], 'emphasized_text_tags': ['b'], 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': 'fd537780925adcd93a05312c63731e02', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': 'ae522cc896cbc78c4d31463c166aa1ae'}, page_content='b) The TL shall assess whether the generation mechanism induces common strings or other common patterns in the resulting passwords.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'link_texts': ['https://www.ncsc.gov.uk/static-assets/documents/PwnedPasswordsTop100k.txt'], 'link_urls': ['https://www.ncsc.gov.uk/static-assets/documents/PwnedPasswordsTop100k.txt'], 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': 'fd537780925adcd93a05312c63731e02', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': '6a88bf5b3ccb9353f9b9dc3dfaf720c4'}, page_content='NOTE 2: Common strings can be those contained in password dictionaries, such as for example: https://www.ncsc.gov.uk/static-assets/documents/PwnedPasswordsTop100k.txt.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'emphasized_text_contents': ['shall'], 'emphasized_text_tags': ['b'], 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': 'fd537780925adcd93a05312c63731e02', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': 'c9d2eaf6653837b93f7ee0591cfaa273'}, page_content='c) The TL shall assess whether the generation mechanism induces passwords, that are related in an obvious way to public information.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': 'fd537780925adcd93a05312c63731e02', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': '0cd0ea5cc622e6a0cf82a7956157c97d'}, page_content='NOTE 3: Public information can be MAC addresses, Wi-Fi® SSIDs, name, type and description of the device.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'emphasized_text_contents': ['shall'], 'emphasized_text_tags': ['b'], 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': 'fd537780925adcd93a05312c63731e02', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': '7c5fd0168bade20f1802a18744357b4c'}, page_content='d) The TL shall assess whether the generation mechanism induces passwords, that are considered appropriate in terms of complexity.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': 'fd537780925adcd93a05312c63731e02', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': '273baaae96b1915de941971496d04b14'}, page_content="NOTE 4: In this context complexity is linked to the probability of guessing the password while applying the information an attacker has. The length of a password is one important aspect to consider for a password's complexity."),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 3, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '93bbcc216c2cd901d8339757937aadbb', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'Title', 'element_id': '6114376d06673ab581b866fe17dc7c5d'}, page_content='Assignment of verdict'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '6114376d06673ab581b866fe17dc7c5d', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': '91d1ea87885e6220fd96efa64a8b958f'}, page_content='The verdict PASS is assigned if:'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 1, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '6114376d06673ab581b866fe17dc7c5d', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'ListItem', 'element_id': '372a942d4840b5ac9c4fa8f8ba03addd'}, page_content='no obvious regularities in pre-installed passwords are found; and'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 1, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '6114376d06673ab581b866fe17dc7c5d', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'ListItem', 'element_id': '80c013fb6b68de118641906fa3ab0de0'}, page_content='no common strings or other common patterns in pre-installed passwords are found; and'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 1, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '6114376d06673ab581b866fe17dc7c5d', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'ListItem', 'element_id': 'b67f4d98ab413431e81ce897b551d7a2'}, page_content='the generation mechanisms for pre-installed passwords do not induce passwords, that are related in an obvious way to public information; and'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 1, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '6114376d06673ab581b866fe17dc7c5d', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'ListItem', 'element_id': '3e16e054461cb67e78b4501b42119b65'}, page_content='the generation mechanisms for pre-installed passwords are considered appropriate in terms of complexity.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '6114376d06673ab581b866fe17dc7c5d', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': 'aafbb65b287dbfc1f60940d3722a1797'}, page_content='The verdict FAIL is assigned otherwise.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 2, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '59b3c9b6ddb30fc58aa688730ed835a7', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'Title', 'element_id': '4d2d69b5847d1a827c156184308a2bd0'}, page_content='5.1.2.2 Test case 5.1-2-2 (functional)'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 3, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '4d2d69b5847d1a827c156184308a2bd0', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'Title', 'element_id': '7f6441a56b7e4cfe325526325bbb8f09'}, page_content='Test purpose'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '7f6441a56b7e4cfe325526325bbb8f09', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': '11e265c19da91ad996bd13a576903175'}, page_content='The purpose of this test case is the functional assessment of the generation mechanisms of pre-installed passwords.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'emphasized_text_contents': ['shall'], 'emphasized_text_tags': ['b'], 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '7f6441a56b7e4cfe325526325bbb8f09', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': 'cdc3b17228eaf86bd096944217d2de66'}, page_content='a) For each authentication mechanism in IXIT 1-AuthMech using pre-installed passwords according to "Authentication Factor", the TL shall functionally assess whether the generation mechanism is plausibly implemented in accordance to the description in "Password Generation Mechanism".'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '7f6441a56b7e4cfe325526325bbb8f09', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': '6cd1c1f53b71badc76c1db05a7feff8a'}, page_content='EXAMPLE: The description of the "Password Generation Mechanism" states, that passwords consist of 8 digits containing at least one character of each group uppercase letters, lowercase letters and numbers.The verification that the corresponding passwords of the DUT match the given length of 8 digits, containing at least one character of the stated groups and do not contain special characters can be helpful to collect an indication.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 3, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '4d2d69b5847d1a827c156184308a2bd0', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'Title', 'element_id': '33fb321bbb4fc3cd4dd2b9259e5e7913'}, page_content='Assignment of verdict'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '33fb321bbb4fc3cd4dd2b9259e5e7913', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': '220fb14280970d93d6d31becb23c5e05'}, page_content='The verdict PASS is assigned if:'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 1, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '33fb321bbb4fc3cd4dd2b9259e5e7913', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'ListItem', 'element_id': 'ba502671768dc6bbaebec03a09bb92e6'}, page_content='for each pre-installed password there is no indication, that its generation differs from the generation mechanism described in the IXIT.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '33fb321bbb4fc3cd4dd2b9259e5e7913', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': '1d8076c5f072be5aba0f1578e09879ba'}, page_content='The verdict FAIL is assigned otherwise.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 1, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': 'c3476ae1b58aa6c20b459888a501930e', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'Title', 'element_id': 'a102ad34536cf2f7639b684de37f7e7e'}, page_content='5.1.3 Test Group 5.1-3'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 2, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': 'a102ad34536cf2f7639b684de37f7e7e', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'Title', 'element_id': '9957a7a122cf3bd4c4aff2787f117517'}, page_content='5.1.3.0 Test Group Objective'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '9957a7a122cf3bd4c4aff2787f117517', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': '27053284d426082ce6ec7956bd193e87'}, page_content='The test group addresses the provision 5.1-3.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '9957a7a122cf3bd4c4aff2787f117517', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': '24da058a3601277d2592f9875c2820f5'}, page_content='According to ETSI TS 103 645 [1]/ETSI EN 303 645 [2] best practice cryptography is defined as cryptography that is suitable for the corresponding use case and has no indication of a feasible attack with current readily available techniques.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '9957a7a122cf3bd4c4aff2787f117517', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': '1cd8d7ec8f242593b48088dc627e533e'}, page_content='The objective of this test group is to assess, firstly, whether the cryptographic methods provide the security guarantees that are necessary for the authentication mechanisms and, secondly, whether the cryptographic methods are not known to be vulnerable to a feasible attack.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 2, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': 'a102ad34536cf2f7639b684de37f7e7e', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'Title', 'element_id': '6388fb13360445f179dd1f7a1a3ea515'}, page_content='5.1.3.1 Test case 5.1-3-1 (conceptual)'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 3, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '6388fb13360445f179dd1f7a1a3ea515', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'Title', 'element_id': '0b300a13e07946966c051dd0087323cf'}, page_content='Test purpose'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '0b300a13e07946966c051dd0087323cf', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': '31a9c8696a9b1772c908d786aa2c3464'}, page_content='The purpose of this test case is the conceptual assessment of the cryptography used for the authentication mechanisms concerning the use of best practice cryptography (a-c) and the vulnerability to a feasible attack d).'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 3, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '6388fb13360445f179dd1f7a1a3ea515', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'Title', 'element_id': '2bb22c684f43db0341b54b7a6a11d5bf'}, page_content='Test units'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '2bb22c684f43db0341b54b7a6a11d5bf', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': '339bc24962322cf760d0da440c0358a0'}, page_content='a) For each authentication mechanism in IXIT 1-AuthMech used to authenticate users against the DUT, the TL shall assess whether the "Security Guarantees" are appropriate for the use case of user authentication, at least integrity and authenticity are required to be fulfilled.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '2bb22c684f43db0341b54b7a6a11d5bf', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': 'e746b0e89a1800a3746aafef40fd5f33'}, page_content='b) For each authentication mechanism in IXIT 1-AuthMech used to authenticate users against the DUT, the TL shall assess whether the mechanism according to "Description" is appropriate to achieve the "Security Guarantees".'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '2bb22c684f43db0341b54b7a6a11d5bf', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': '0ca047296c41fda77322c7671bd059ad'}, page_content='NOTE 1: A holistic approach is required to assess the security of the mechanism.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'emphasized_text_contents': ['shall', 'shall', 'shall'], 'emphasized_text_tags': ['b', 'b', 'b'], 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '2bb22c684f43db0341b54b7a6a11d5bf', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': '94d65fbb370269e469ad227bb07f231e'}, page_content='c) For each authentication mechanism in IXIT 1-AuthMech used to authenticate users against the DUT, the TL shall assess whether the "Cryptographic Details" are considered as best practice cryptography for the use case of user authentication based on a reference catalogue. If "Cryptographic Details" are not included in a reference catalogue for the corresponding use case (e.g. novel cryptography), the SO shall provide evidences, e.g. a risk analysis, to justify the cryptography is appropriate as best practice for the use case. In such case the TL shall assess whether the evidence is appropriate and reliable for the use case.'),
# ...
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '61a2ffc5f39a4506af33c93a84adf3c4', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': '9308d0e95b33c035d4b4c8990d59e33c'}, page_content='The verdict PASS is assigned if:'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 1, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '61a2ffc5f39a4506af33c93a84adf3c4', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'ListItem', 'element_id': '1141c105143ac3e8503d6d4aadcd505b'}, page_content='for every network or logical interface that is marked as enabled in the IXIT documentation, there is a purpose that provides a valid justification for the interface to be enabled.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '61a2ffc5f39a4506af33c93a84adf3c4', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': 'f274be920e830d6399f99927994b418f'}, page_content='The verdict FAIL is assigned otherwise.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 2, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': 'f7cb9e7b706d39210376c7d38b598acd', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'Title', 'element_id': '45b053b6b54f4e064747cdb6b84c9495'}, page_content='5.6.1.2 Test case 5.6-1-2 (functional)'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 3, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '45b053b6b54f4e064747cdb6b84c9495', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'Title', 'element_id': 'a683272a410446fcc8cfdbf35f6d2425'}, page_content='Test purpose'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': 'a683272a410446fcc8cfdbf35f6d2425', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': '6eb9fa2741629f5f7f1c5abb12310310'}, page_content='The purpose of this test case is the functional assessment of the network and logical interfaces of the DUT a) and the completeness of the IXIT documentation b).'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 3, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '45b053b6b54f4e064747cdb6b84c9495', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'Title', 'element_id': '968c9c2476f80614c4d1db05a646f0aa'}, page_content='Test units'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'emphasized_text_contents': ['shall'], 'emphasized_text_tags': ['b'], 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '968c9c2476f80614c4d1db05a646f0aa', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': '1c21d57ff946f06b6fb013e2bb1ed9fa'}, page_content='a) For each network and logical interface in IXIT 15-Intf, the TL shall functionally check whether the status of the interface matches the "Status" in the IXIT documentation.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '968c9c2476f80614c4d1db05a646f0aa', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': '911e2cf6200e0952fe231e00e46c7a61'}, page_content='NOTE: A possible method to analyse an interface is to use protocol testing tools in a black-box setting and to infer from the obtained information whether the interface is enabled or disabled on the DUT. For cases where the DUT provides an indication (e.g. a visual indication of connectors, antennas and components) whether the interface is enabled or disabled, the accessibility test allows to confirm or disprove the indication.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'emphasized_text_contents': ['shall'], 'emphasized_text_tags': ['b'], 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '968c9c2476f80614c4d1db05a646f0aa', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': 'a7fa12a37d72cd20b5ee68ba3ae65802'}, page_content='b) The TL shall functionally assess whether network or logical interfaces that are not documented in IXIT 15-Intf are available via a network interface on the DUT.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '968c9c2476f80614c4d1db05a646f0aa', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': '2a9ec9dc4ef03dff25c22af1f3cc7b6e'}, page_content='EXAMPLE: Network scanning tools allow for discovery of network or logical interfaces.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 3, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '45b053b6b54f4e064747cdb6b84c9495', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'Title', 'element_id': 'd092eb54247ec5bb4f0e972b7a227870'}, page_content='Assignment of verdict'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': 'd092eb54247ec5bb4f0e972b7a227870', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': 'bb92f0f338c2badec0a51fd7bd796aff'}, page_content='The verdict PASS is assigned if:'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 1, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': 'd092eb54247ec5bb4f0e972b7a227870', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'ListItem', 'element_id': '9835e6b083457052540c344752683504'}, page_content='every documented network or logical interface that is marked as disabled in the IXIT documentation is found to be disabled or not accessible on the DUT; and'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 1, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': 'd092eb54247ec5bb4f0e972b7a227870', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'ListItem', 'element_id': '319595eab151817a8568fc0212a541e9'}, page_content='every discovered network and logical interface is documented in the IXIT.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': 'd092eb54247ec5bb4f0e972b7a227870', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': 'a982785db2df89a9ca0c0ea773d1ec29'}, page_content='The verdict FAIL is assigned otherwise.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 1, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '3a90c45542b93df27d9c4a2d27ae2ed3', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'Title', 'element_id': '7eaf9572c97ea2a6ac28779dd1cb39c7'}, page_content='5.6.2 Test Group 5.6-2'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 2, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '7eaf9572c97ea2a6ac28779dd1cb39c7', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'Title', 'element_id': '8f57af58c87d613a8317820879516eb6'}, page_content='5.6.2.0 Test Group Objective'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '8f57af58c87d613a8317820879516eb6', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': '00d42448eea654330223a8294dacf478'}, page_content='The test group addresses the provision 5.6-2.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '8f57af58c87d613a8317820879516eb6', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': '481d9f50ef2fd1c0413891f3eeb7fbeb'}, page_content='The principle of minimization applied to security-relevant information in unauthenticated context dictates that only such information that is necessary for device or service operations in unauthenticated context are disclosed. It is to be noted that the manufacturer might not be able to minimize disclosed information if requirements exist to conform to standardized protocols which, by design, disclose more information than necessary.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 0, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'Title', 'element_id': 'f27621d94f9030c27a37d270341758dc'}, page_content='EXAMPLE: MAC address in Ethernet, Bluetooth® and Wi-Fi®, ARP, DNS.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 3, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': 'f27621d94f9030c27a37d270341758dc', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'Title', 'element_id': '6d1bcfdd10342fae44357cb8201c2d6b'}, page_content='5.6.2.1 Test case 5.6-2-1 (conceptual)'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 2, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': 'f27621d94f9030c27a37d270341758dc', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'Title', 'element_id': '59e29563ecd9545cabc1385cb25b29d1'}, page_content='Test purpose'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '59e29563ecd9545cabc1385cb25b29d1', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': '4d4324d41f73d99cb753e461e48ea17c'}, page_content='The purpose of this test case is the conceptual assessment of the information disclosed by network interfaces without authentication in the initialized state.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 3, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '59e29563ecd9545cabc1385cb25b29d1', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'Title', 'element_id': '7b596e36664f166eafca5a50af3dd686'}, page_content='Test units'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'emphasized_text_contents': ['shall'], 'emphasized_text_tags': ['b'], 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '7b596e36664f166eafca5a50af3dd686', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': '734dffbbbdb2600c82e6e0013d62a882'}, page_content='a) For each network interface in IXIT 15-Intf, the TL shall assess whether the "Disclosed Information" disclosed by the interface without authentication in the initialized state and indicated as not security-relevant, is however security-relevant.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'emphasized_text_contents': ['shall'], 'emphasized_text_tags': ['b'], 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '7b596e36664f166eafca5a50af3dd686', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'NarrativeText', 'element_id': '53f10ae2afccb073d653ac7df7c4884c'}, page_content='b) For each network interface in IXIT 15-Intf, the TL shall assess whether the "Disclosed Information" disclosed by the interface without authentication in the initialized state and indicated as security-relevant, is necessary for the operation of the DUT.'),
#  Document(metadata={'source': '/home/yuva/dev/LLM_Examples/docs/ts_103701_only_test_scenario.md', 'category_depth': 3, 'last_modified': '2024-09-21T02:18:19', 'languages': ['eng'], 'parent_id': '59e29563ecd9545cabc1385cb25b29d1', 'filetype': 'text/markdown', 'file_directory': '/home/yuva/dev/LLM_Examples/docs', 'filename': 'ts_103701_only_test_scenario.md', 'category': 'Title', 'element_id': 'b6ad47462f4b0dd4dd6a79b4f6bbfd8f'}, page_content='Assignment of verdict'),
#  ...]

# %% [markdown]
# # Similarity search

# %%
import pandas as pd

df = pd.read_csv("../docs/EN303645問題彙整(verdict)_台科大.csv")
df
# Out:
#    provision  status  support  \
# 0     5.1-1    MC(1)      NaN
# 1      5.1-2   MC(2)      NaN
# 2      5.1-3       M      NaN
# 3      5.1-4   MC(8)      NaN
# 4      5.1-5   MC(5)      NaN
# ..       ...     ...      ...
# 62       6.1       M      NaN
# 63       6.2   MC(7)      NaN
# 64       6.3       M      NaN
# 65       6.4   RC(6)      NaN
# 66       6.5   MC(6)      NaN
#
#                                                detail  \
# 0   如果使用密碼並且處於出廠預設設置以外的任何狀態，則所有消費者物聯網設備密碼應為每個設備獨有的...
# 1   如果每台設備使用預安裝的密碼是獨有的，則應使用一種機制生成這些密碼，以降低對某種或某類設備類...
# 2          用以對裝置鑑別使用者之鑑別機制，應使用對技術、風險及使用的性質適切之最佳實務密碼學。
# 3   當使用者可以針對設備進行身份驗證時，設備應向使用者或管理員提供簡單的機制來更改所使用的身份驗證值。
# 4           當裝置係非受限制時，其應具可用之機制，使得經由網路介面暴力攻擊鑑別機制為不切實際。
# ..                                                ...
# 62  製造商應向消費者提供清晰透明的資訊，說明每個設備和服務所處理的個人資料內容、使用方式、處理者...
# 63                      處理個人資料之依據係消費者的同意，應以有效方式取得此同意。
# 64                          同意處理其個人資料的消費者有權隨時撤回其個人資料。
# 65  若由消費者 IoT 裝置及服務蒐集遙測資料，則宜將個人資料之處理保持於預期功能性所必要的最低限度。
# 66  若由消費者 IoT 裝置及服務中蒐集遙測資料，應向消費者提供有關蒐集哪些遙測資料、如何利用、...
#
#                                         Test Scenario  \
# 0   問題：當使用密碼且處於出廠預設值（例如「admin」）以外的任何狀態時，所有消費者物聯網裝置...
# 1   預先安裝的每台設備的唯一密碼應透過一種機制生成，該機制可降低針對某一類或類型設備的自動攻擊的...
# 2   身份驗證資料在使用者和裝置之間傳輸時應進行加密。\n注意：傳輸通常可以在行動應用程式和裝置之...
# 3   （範例：密碼或指紋類型的令牌）。\n\n問題：\n1. 如果設備允許使用者認證，認證值tok...
# 4   當一個設備具有物理上的限制時，可能在數據處理能力、數據通信能力、數據存儲能力或與用戶交互能力...
# ..                                                ...
# 62  許多消費者物聯網設備都會處理個人資料。 預計製造商將在消費性物聯網設備中提供支援保護此類個人...
# 63  注意：「以有效方式」取得同意通常涉及讓消費者自由、明顯和明確地選擇其個人資料是否可用於特定目...
# 64  注意：消費者希望能夠透過適當配置物聯網設備和服務功能來保護自己的隱私。問題：1. 同意處理其...
# 65  問題：\n如果遙測資料是從消費者物聯網設備和服務收集的：\n1. 個人資料的處理是否會維持在...
# 66  問題：\n如果正在收集遙測數據：\n對於從消費者物聯網設備和服務收集的遙測數據，是否會向消費...
#
#                                                answer  reason  result  \
# 0   使用者密碼透過wizard由使用者設定且與MAC Address/SN無相關性，且無法反算或...     NaN     NaN
# 1   工廠生產線上的工具為每個設備隨機產生一個密碼，將其寫入設備閃存，然後列印在標籤上，讓使用者開...     NaN     NaN
# 2   本機驗證透過 HMAC-SHA256 質詢使用使用者設定的密碼完成。 \n透過 HTTPs ...     NaN     NaN
# 3   1. 登入裝置的裝置密碼，可以在app/web介面修改，修改前必須經過管理會話身分認證。\n...     NaN     NaN
# 4       本地認證機制在連續5次錯誤登錄嘗試後鎖定API訪問60秒，這大大延長了暴力破解攻擊的時間。     NaN     NaN
# ..                                                ...     ...     ...
# 62                       設備本身並無存儲任何除了登入帳號或連線上網之外的任何資訊     NaN     NaN
# 63                                                NaN     NaN     NaN
# 64                   D-Link 除了登入的帳號密碼之外，不會存儲有關個人隱私資料。     NaN     NaN
# 65                   D-Link 除了登入的帳號密碼之外，不會存儲有關個人隱私資料。     NaN     NaN
# 66  在帳戶建立和裝置註冊過程中，所有可能透過雲端服務收集的資料都會被充分了解。 D-Link 入...     NaN     NaN
#
#                                               解釋  \
# 0                                       密碼是如何建立的
# 1                                   預設密碼的產生機制是什麼
# 2                           身份驗證資料在傳輸過程中如何進行加密保護
# 3      身份驗證後，驗證值(密碼、token..等)應有簡單的機制來更改所使用的身份驗證值
# 4                             當裝置是非受限時，要可以防止暴力破解
# ..                                           ...
# 62  製造商應向消費者說明每個設備和服務處理的個人資料內容、使用方式和目的，包括參與的第三方。
# 63                      處理個人資料需取得消費者同意，並以有效方式取得。
# 64                          消費者有權隨時撤回其個人資料處理的同意。
# 65                            處理個人資料應保持在最小必要範圍內。
# 66         製造商應向消費者提供蒐集哪些遙測資料、如何利用、利用對象及利用目的的資訊。
#
#                                              criteria
# 0   The verdict PASS is assigned if:        • all ...
# 1   The verdict PASS is assigned if:        • a me...
# 2   The verdict PASS is assigned if:        • the ...
# 3   The verdict PASS is assigned if:        • a si...
# 4   The verdict PASS is assigned if:        • the ...
# ..                                                ...
# 62  The verdict PASS is assigned if:        • the ...
# 63  The verdict PASS is assigned if:        • obta...
# 64  The verdict PASS is assigned if:        • the ...
# 65  The verdict PASS is assigned if:        • the ...
# 66  The verdict PASS is assigned if:        • the ...
#
# [67 rows x 10 columns]

# %% [markdown]
# ### One row test

# %%
row = df.iloc[10]
query = f"控制措施{row['provision']}，detail:{row['detail']}"
question = f"{query}\
    How to determine PASS or FAIL from the Assignment of verdict of Test group {row['provision']}.\
    Output example: The verdict PASS is assigned if:\
    • the publication of software update support period is understandable and comprehensible for a user with limited technical knowledge. \
    The verdict FAIL is assigned otherwise. "

print(f"{row['provision']}\n")

# similarity search
relevant_docs = hf_vectorstore.search(question, search_type="similarity", k=150)

# filter out the verdict
verdicts = []
for doc in relevant_docs:
    print(doc.metadata)
    # if "Assignment of verdict" in metadata
    if "Header 4" in doc.metadata:
        if doc.metadata["Header 4"] == "Assignment of verdict":
            # Header 2 is like 【5.1.1 Test group 5.1-1】, turn it into [5, 1, 1] to compare with the provision
            if re.split(r"[.-]", doc.metadata["Header 2"].split(" ")[-1]) == re.split(
                r"[.-]", row["provision"].strip()
            ):
                verdicts.append(doc)

for verdict in verdicts:
    print(verdict.metadata)
    print("\n")
# Out:
# 5.3-3
#
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.13 Test group 5.3-13', 'Header 3': '5.3.13.1 Test case 5.3-13-1 (conceptual)', 'Header 4': 'Assignment of verdict', '_id': '098da102f4c545368acfa4a52095ca0a', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.4 Test Group 5.3-4', 'Header 3': '5.3.4.1 Test case 5.3-4-1 (conceptual)', 'Header 4': 'Assignment of verdict', '_id': '7960b3005c8a46f9a17db8d0c0a5a35d', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.5 Test Group 5.3-5', 'Header 3': '5.3.5.1 Test case 5.3-5-1 (conceptual)', 'Header 4': 'Assignment of verdict', '_id': '4e0e3bfcbdf945d08c140f13053d78b2', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.12 Test group 5.3-12', 'Header 3': '5.3.12.1 Test case 5.3-12-1 (conceptual)', 'Header 4': 'Assignment of verdict', '_id': '3e29f40ed3ef445aa02f01e3ce71043b', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.1 Test Group 5.3-1', 'Header 3': '5.3.1.0 Test Group Objective', 'Header 4': 'Assignment of verdict', '_id': '085f62241b544300a04268f8129473ce', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.9 Test Group 5.3-9', 'Header 3': '5.3.9.1 Test case 5.3-9-1 (conceptual)', 'Header 4': 'Assignment of verdict', '_id': '3d5789e787b54fcc8efe24a023348382', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.11 Test Group 5.3-11', 'Header 3': '5.3.11.1 Test case 5.3-11-1 (conceptual)', 'Header 4': 'Assignment of Verdict', '_id': '78547aab733744a59908a894753c5ebc', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.6 Test Group 5.3-6', 'Header 3': '5.3.6.1 Test case 5.3-6-1 (conceptual)', 'Header 4': 'Assignment of verdict', '_id': '1ac41230b1454bd7b2dfef80b8ee1431', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.5 Test Group 5.3-5', 'Header 3': '5.3.5.0 Test Group Objective', '_id': 'aa88282be50c4485b87aacf72d3d1cf3', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.1 Test Group 5.3-1', 'Header 3': '5.3.1.0 Test Group Objective', '_id': 'c9642e8877e04df78d79560dc858d777', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.4 Test Group 5.1-4', 'Header 3': '5.1.4.2 Test case 5.1-4-2 (functional)', 'Header 4': 'Assignment of verdict', '_id': '5b79c367949f4635a8daa9b893c8cbce', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.10.1 Test Case 5.3-10-1 (Conceptual/Functional)', 'Header 4': 'Assignment of Verdict', '_id': 'dc0e02914f384c4bae55812a154b0470', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.5 Tso 5.5: Communicate Securely', 'Header 2': '5.5.3 Test Group 5.5-3', 'Header 3': '5.5.3.1 Test case 5.5-3-1 (conceptual)', 'Header 4': 'Assignment of verdict', '_id': 'ee8e448a5e9c4bd19a6b68a54e063030', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.4 Test Group 5.3-4', 'Header 3': '5.3.4.0 Test Group Objective', '_id': 'e8b62ed2ea374249bbb28d42504c7608', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.3 Test group 5.3-3', 'Header 3': '5.3.3.0 Test group objective', '_id': '7d7ee8fc77bb4a38bf9ccdebcc827d2d', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.6 Tso 5.6: Minimize Exposed Attack Surfaces', 'Header 2': '5.6.5 Test Group 5.6-5', 'Header 3': '5.6.5.1 Test case 5.6-5-1 (conceptual)', 'Header 4': 'Assignment of verdict', '_id': 'aaf7f01d3d8b45d1b52ef284b5ba8ad4', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.14 Test Group 5.3-14', 'Header 3': '5.3.14.1 Test case 5.3-14-1 (conceptual)', 'Header 4': 'Assignment of verdict', '_id': '06c6d44e54fa4b70b985e95f08009d4b', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.12 Test group 5.3-12', 'Header 3': '5.3.12.0 Test group objective', '_id': '52fa44d156244eed8119466ad04c29a4', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.6 Test Group 5.3-6', 'Header 3': '5.3.6.2 Test case 5.3-6-2 (functional)', 'Header 4': 'Assignment of verdict', '_id': '7540b6e3c60d411ebc7bd16483d33350', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.7 Test Group 5.3-7', 'Header 3': '5.3.7.1 Test case 5.3-7-1 (conceptual)', 'Header 4': 'Assignment of verdict', '_id': '45d2dd1e9a0e45a1a3412c273c23ab5f', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.13 Test group 5.3-13', 'Header 3': '5.3.13.0 Test group objective', '_id': '3694db59e12d46ffbfdab351e277cc98', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': 'Test Units', 'Header 4': 'Assignment of verdict', '_id': '667de2340c844d60a263c3595b9000c6', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.12 Tso 5.12: Make Installation And Maintenance Of Devices Easy', 'Header 2': '5.12.1 Test group 5.12-1', 'Header 3': '5.12.1.2 Test case 5.12-1-2 (functional)', 'Header 4': 'Assignment of verdict', '_id': '0553cdd467e64740960951db1573c731', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.2 Test group 5.3-2', 'Header 3': '5.3.2.0 Test group objective', '_id': 'fedf7a34dcce488898502ba4d2f51d36', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.14 Test Group 5.3-14', 'Header 3': '5.3.14.2 Test case 5.3-14-2 (functional)', 'Header 4': 'Assignment of verdict', '_id': 'fdff4b6af0f94347b917f2585fd4ea7d', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.12 Tso 5.12: Make Installation And Maintenance Of Devices Easy', 'Header 2': '5.12.1 Test group 5.12-1', 'Header 3': '5.12.1.1', 'Header 4': 'Assignment of verdict', '_id': 'df4ef189d1e8406da8810d8f3c3fd10f', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.3 Test group 5.3-3', 'Header 3': '5.3.3.1 Test case 5.3-3-1 (conceptual)', 'Header 4': 'Test units', '_id': '1279c4669dc14e1ebac37455c6fcdf6b', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.5 Tso 5.5: Communicate Securely', 'Header 2': '5.5.5 Test Group 5.5-5', 'Header 3': '5.5.5.1 Test case 5.5-5-1 (conceptual)', 'Header 4': 'Assignment of verdict', '_id': '4f3a0a2a7394402890bed9fe198b91a7', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.5 Tso 5.5: Communicate Securely', 'Header 2': '5.5.4 Test Group 5.5-4', 'Header 3': '5.5.4.1 Test case 5.5-4-1 (conceptual)', 'Header 4': 'Assignment of verdict', '_id': '127254b25a144a48bccbddb319b44bc5', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.4 Test Group 5.1-4', 'Header 3': '5.1.4.1 Test case 5.1-4-1 (conceptual)', 'Header 4': 'Assignment of verdict', '_id': '6b39b8eaf8df4b86aaeba2ad1cabc0f2', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.7 Tso 5.7: Ensure Software Integrity', 'Header 2': '5.7.1 Test Group 5.7-1', 'Header 3': '5.7.1.1 Test case 5.7-1-1 (conceptual)', 'Header 4': 'Assignment of verdict', '_id': 'e0bad41190b84b4b8bba3f6f4c4c3f32', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.7 Tso 5.7: Ensure Software Integrity', 'Header 2': '5.7.2 Test Group 5.7-2', 'Header 3': '5.7.2.1 Test case 5.7-2-1 (conceptual)', 'Header 4': 'Assignment of verdict', '_id': '9627ee8ec7794846977366a83d345b05', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.8 Test Group 5.3-8', 'Header 3': '5.3.8.1 Test case 5.3-8-1 (conceptual)', 'Header 4': 'Assignment of verdict', '_id': '03069a9dd991429d8059eae3b7891741', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.1 Test Group 5.3-1', 'Header 3': '5.3.1.0 Test Group Objective', 'Header 4': 'Test units', '_id': '033b868653234ba095f0fb2592c2b54e', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.4 Tso 5.4: Securely Store Sensitive Security Parameters', 'Header 2': '5.4.1 Test Group 5.4-1', 'Header 3': '5.4.1.1 Test case 5.4-1-1 (conceptual)', 'Header 4': 'Assignment of verdict', '_id': 'edc0fb7ef5b14574b7bbd3808c68352a', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.4 Tso 5.4: Securely Store Sensitive Security Parameters', 'Header 2': '5.4.4 Test Group 5.4-4', 'Header 3': '5.4.4.1 Test case 5.4-4-1 (conceptual)', 'Header 4': 'Assignment of verdict', '_id': '8599ee0ffd0b433691fda73d9506bc8b', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.6 Tso 5.6: Minimize Exposed Attack Surfaces', 'Header 2': '5.6.9 Test Group 5.6-9', 'Header 3': '5.6.9.1 Test case 5.6-9-1 (conceptual)', 'Header 4': 'Assignment of verdict', '_id': '7ad5877046b746babb4358875b349b49', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.4 Tso 5.4: Securely Store Sensitive Security Parameters', 'Header 2': '5.4.3 Test Group 5.4-3', 'Header 3': '5.4.3.2 Test Case 5.4-3-2 (Functional)', 'Header 4': 'Assignment of verdict', '_id': 'c3b55a796b854cedb1f80d21d32e1e29', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.12 Tso 5.12: Make Installation And Maintenance Of Devices Easy', 'Header 2': '5.12.1 Test group 5.12-1', 'Header 3': '5.12.1.0 Test group objective', '_id': 'a74c476e9661406793bb0b93b02192e0', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.6 Tso 5.6: Minimize Exposed Attack Surfaces', 'Header 2': '5.6.4 Test Group 5.6-4', 'Header 3': '5.6.4.1 Test case 5.6-4-1 (conceptual)', 'Header 4': 'Assignment of verdict', '_id': 'df3c1f77fb7a428991b615f6f85aa245', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.12 Tso 5.12: Make Installation And Maintenance Of Devices Easy', 'Header 2': '5.12.3 Test Group 5.12-3', 'Header 3': '5.12.3.0 Test Group Objective', '_id': '2a89b692c0a045a4be5d080551719282', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.6 Test Group 5.3-6', 'Header 3': '5.3.6.2 Test case 5.3-6-2 (functional)', 'Header 4': 'Test units', '_id': 'efdbe2a4f76c47b9b52f2cc6ebf6467c', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.6 Tso 5.6: Minimize Exposed Attack Surfaces', 'Header 2': '5.6.1 Test Group 5.6-1', 'Header 3': '5.6.1.1 Test case 5.6-1-1 (conceptual)', 'Header 4': 'Assignment of verdict', '_id': '921de0d3aa4c4a2482336efcca42bbb7', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.2 Test group 5.3-2', 'Header 3': '5.3.2.1 Test case 5.3-2-1 (conceptual)', 'Header 4': 'Assignment of verdict', '_id': 'cbf4dce3943346be8bc3b4f33f8bba23', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.2 Test group 5.3-2', 'Header 3': '5.3.2.2 Test case 5.3-2-2 (functional)', 'Header 4': 'Assignment of verdict', '_id': '07bffe67d00243a89437a77db2506560', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.6 Tso 5.6: Minimize Exposed Attack Surfaces', 'Header 2': '5.6.4 Test Group 5.6-4', 'Header 3': '5.6.4.0 Test group objective', '_id': '7b46e6f0a8c5488b8dcc7acbc9bce9f8', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.3 Test Group 5.1-3', 'Header 3': '5.1.3.1 Test case 5.1-3-1 (conceptual)', 'Header 4': 'Assignment of verdict', '_id': '9fc9d69edec34eb19c6ba95a9bb33eb4', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.6 Tso 5.6: Minimize Exposed Attack Surfaces', 'Header 2': '5.6.4 Test Group 5.6-4', 'Header 3': '5.6.4.2 Test case 5.6-4-2 (functional)', 'Header 4': 'Assignment of verdict', '_id': 'a21bfe31f8c14f258c2fb55bd30346f9', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.13 Test group 5.3-13', 'Header 3': '5.3.13.2 Test case 5.3-13-2 (functional)', 'Header 4': 'Assignment of verdict', '_id': '43612d621cf24db8ad3bcb756231905c', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.4 Tso 5.4: Securely Store Sensitive Security Parameters', 'Header 2': '5.4.3 Test Group 5.4-3', 'Header 3': '5.4.3.1 Test case 5.4-3-1 (conceptual)', 'Header 4': 'Assignment of verdict', '_id': '420eaab42b97492ba3758d4dd8938f7f', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.12 Tso 5.12: Make Installation And Maintenance Of Devices Easy', 'Header 2': '5.12.3 Test Group 5.12-3', 'Header 3': '5.12.3.1 Test Case 5.12-3-1 (Functional)', 'Header 4': 'Assignment of Verdict', '_id': '616781df49a14c959a3adbff980123a5', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.6 Tso 5.6: Minimize Exposed Attack Surfaces', 'Header 2': 'Assignment Of Verdict 5.6.8 Test Group 5.6-8', 'Header 3': '5.6.8.1 Test case 5.6-8-1 (conceptual)', 'Header 4': 'Assignment of verdict', '_id': '6d58bacc86194996be7c561577d8747f', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.6 Tso 5.6: Minimize Exposed Attack Surfaces', 'Header 2': '5.6.7 Test Group 5.6-7', 'Header 3': '5.6.7.1 Test case 5.6-7-1 (conceptual)', 'Header 4': 'Assignment of verdict', '_id': 'aef74e3c9ad3445f818086794587390c', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.9 Tso 5.9: Make Systems Resilient To Outages', 'Header 2': '5.9.1 Test Group 5.9-1', 'Header 3': '5.9.1.1 Test case 5.9-1-1 (conceptual)', 'Header 4': 'Assignment of verdict', '_id': 'f6c18d938cb94eb68f1fc1d82b12c905', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.2 TSO 5.2: Implement a means to manage reports of vulnerabilities', 'Header 2': '5.2.3 Test Group 5.2-3', 'Header 3': '5.2.3.1 Test case 5.2-3-1 (conceptual)', 'Header 4': 'Assignment of verdict', '_id': 'fa6c8a3fbaa84caeb96404a7d32fab39', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.6 Tso 5.6: Minimize Exposed Attack Surfaces', 'Header 2': '5.6.2 Test Group 5.6-2', 'Header 3': 'Test purpose', 'Header 4': 'Assignment of verdict', '_id': 'eec9b6cbdcb34adf950859c2c55f2920', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.6 Test Group 5.3-6', 'Header 3': '5.3.6.1 Test case 5.3-6-1 (conceptual)', 'Header 4': 'Test units', '_id': '6bb02b3686c34414acd8169ed3830df1', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.8 Tso 5.8: Ensure That Personal Data Is Secure', 'Header 2': '5.8.3 Test Group 5.8-3', 'Header 3': '5.8.3.1 Test Case 5.8-3-1 (Functional)', 'Header 4': 'Assignment of Verdict', '_id': 'cdb9d42b44fd4b598a19200c98759651', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.5 Tso 5.5: Communicate Securely', 'Header 2': '5.5.5 Test Group 5.5-5', 'Header 3': '5.5.5.1 Test case 5.5-5-1 (conceptual)', 'Header 4': 'Test units', '_id': 'b6e9a1ad365f4cfc88ffa5647c20eb93', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.2 Test Group 5.1-2', 'Header 3': '5.1.2.2 Test case 5.1-2-2 (functional)', 'Header 4': 'Assignment of verdict', '_id': 'eb39eabe015c45a5a19311974821df89', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.10.1 Test Case 5.3-10-1 (Conceptual/Functional)', 'Header 4': 'Test Units', '_id': '8316176da6cb47a48085d0005a7a587e', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.5 Tso 5.5: Communicate Securely', 'Header 2': '5.5.4 Test Group 5.5-4', 'Header 3': '5.5.4.0 Test Group Objective', '_id': '337454eba93c454ab9b636be8a6dfe5c', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.9 Test Group 5.3-9', 'Header 3': '5.3.9.0 Test Group Objective', '_id': '751fa145478c4341b3b6b11019e92e52', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.11 Tso 5.11: Make It Easy For Users To Delete User Data', 'Header 2': '5.11.4.1 Test Case 5.11-4-1 (Functional)', 'Header 4': 'Assignment of Verdict', '_id': '50b505724727497ab0d3d6ec8741f3f2', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.9 Test Group 5.3-9', 'Header 3': '5.3.9.1 Test case 5.3-9-1 (conceptual)', 'Header 4': 'Test units', '_id': '560edfc1873b4ce3bd32a614a31b45f3', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.5 Tso 5.5: Communicate Securely', 'Header 2': '5.5.3 Test Group 5.5-3', 'Header 3': '5.5.3.0 Test Group Objective', '_id': '8403c37eaa9e4ca68ba16c812131b80e', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.12 Tso 5.12: Make Installation And Maintenance Of Devices Easy', 'Header 2': '5.12.2.1 Test Case 5.12-2-1 (Functional)', 'Header 4': 'Assignment of verdict', '_id': 'b3ed2c53a94d4088b0263fbe83690b97', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.14 Tso 6: Data Protection For Consumer Iot', 'Header 2': '5.14.4 Test group 6-4', 'Header 3': '5.14.4.1 Test case 6-4-1 (conceptual)', 'Header 4': 'Assignment of verdict', '_id': '5a948a1374cc4087b397f9cba1d76dd5', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.5 Tso 5.5: Communicate Securely', 'Header 2': '5.5.5 Test Group 5.5-5', 'Header 3': '5.5.5.0 Test Group Objective', '_id': '6496319e997649ae9ec35cb940372625', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.5 Test Group 5.3-5', 'Header 3': '5.3.5.1 Test case 5.3-5-1 (conceptual)', 'Header 4': 'Test units', '_id': '7cbd7740bb004c3690d520d11a0ba39c', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.4 Tso 5.4: Securely Store Sensitive Security Parameters', 'Header 2': '5.4.1 Test Group 5.4-1', 'Header 3': '5.4.1.2 Test case 5.4-1-2 (functional)', 'Header 4': 'Assignment of verdict', '_id': 'f865febeedad48d19afd9513f67f1519', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.7 Tso 5.7: Ensure Software Integrity', 'Header 2': '5.7.1 Test Group 5.7-1', 'Header 3': '5.7.1.2 Test case 5.7-1-2 (functional)', 'Header 4': 'Assignment of verdict', '_id': '73daa37331564caf8661522f22034e8a', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.5 Tso 5.5: Communicate Securely', 'Header 2': '5.5.2 Test Group 5.5-2', 'Header 3': '5.5.2.1  Test case 5.5-2-1 (conceptual)', 'Header 4': 'Assignment of verdict', '_id': '2027b37dc15e4dbaa072a83ed5148737', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.2 Test group 5.3-2', 'Header 3': '5.3.2.2 Test case 5.3-2-2 (functional)', 'Header 4': 'Test purpose', '_id': '17e127342fb543f3ba770823e6e3abed', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.2 Test Group 5.1-2', 'Header 3': '5.1.2.1 Test case 5.1-2-1 (conceptual)', 'Header 4': 'Assignment of verdict', '_id': '7d0beb3ee71c42d79c4a23f9be635c18', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.9 Tso 5.9: Make Systems Resilient To Outages', 'Header 2': '5.9.3 Test Group 5.9-3', 'Header 3': '5.9.3.0 Test Group Objective', '_id': 'e4ae57401f5b471e88bca8787c86b549', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.7 Tso 5.7: Ensure Software Integrity', 'Header 2': '5.7.2 Test Group 5.7-2', 'Header 3': '5.7.2.2 Test case 5.7-2-2 (functional)', 'Header 4': 'Assignment of verdict', '_id': '67f9c67caf374de4b067ac257ff43299', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.11 Tso 5.11: Make It Easy For Users To Delete User Data', 'Header 2': '5.11.3 Test Group 5.11-3', 'Header 3': '5.11.3.1 Test case 5.11-3-1 (functional)', 'Header 4': 'Assignment of verdict', '_id': '976ee521290b44d39d0b04a47016c00f', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.4 Test Group 5.3-4', 'Header 3': '5.3.4.1 Test case 5.3-4-1 (conceptual)', 'Header 4': 'Test units', '_id': '44e05803272c4c30abaac3da789d063c', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.12 Test group 5.3-12', 'Header 3': '5.3.12.1 Test case 5.3-12-1 (conceptual)', 'Header 4': 'Test units', '_id': 'ea9ad3bd21754dc2ad7f83dddba0cc61', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.6 Tso 5.6: Minimize Exposed Attack Surfaces', 'Header 2': '5.6.3 Test Group 5.6-3', 'Header 3': '5.6.3.2 Test case 5.6-3-2 (functional)', 'Header 4': 'Assignment of verdict', '_id': '51acf4612efe430297d2ae748f3c22be', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.8 Test Group 5.3-8', 'Header 3': '5.3.8.1 Test case 5.3-8-1 (conceptual)', 'Header 4': 'Test units', '_id': 'b0eb539b9edd4a718563d6b901ff285e', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.5 Tso 5.5: Communicate Securely', 'Header 2': '5.5.4 Test Group 5.5-4', 'Header 3': '5.5.4.2 Test case 5.5-4-2 (functional)', 'Header 4': 'Test units', '_id': '6357039a83344b30b8d5a754c30b84e8', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.14 Test Group 5.3-14', 'Header 3': '5.3.14.2 Test case 5.3-14-2 (functional)', 'Header 4': 'Test units', '_id': '132ee97ba0ae48bbbdd52b2c6eab44ab', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': 'Test Units', '_id': '986d9798814f4cf4b60f7b31fdbe6397', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.9 Tso 5.9: Make Systems Resilient To Outages', 'Header 2': '5.9.3 Test Group 5.9-3', 'Header 3': '5.9.3.2 Test case 5.9-3-2 (functional)', 'Header 4': 'Assignment of Verdict', '_id': '0390eacf74ca4a04974d3931d0a31363', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.5 Tso 5.5: Communicate Securely', 'Header 2': '5.5.8 Test Group 5.5-8', 'Header 3': '5.5.8.1 Test case 5.5-8-1 (conceptual)', 'Header 4': 'Assignment of verdict', '_id': 'e9f3b5596260486e9b12c9e457a893f8', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.7 Test Group 5.3-7', 'Header 3': '5.3.7.0 Test Group Objective', '_id': 'da00df6dd42a468ca29fa44f2cbe2ee6', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.6 Tso 5.6: Minimize Exposed Attack Surfaces', 'Header 2': '5.6.2 Test Group 5.6-2', 'Header 3': '5.6.2.2 Test case 5.6-2-2 (functional)', 'Header 4': 'Assignment of verdict', '_id': 'e8cdd6af3d19454eaf481f2c8cfb37c8', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.4 Tso 5.4: Securely Store Sensitive Security Parameters', 'Header 2': '5.4.4 Test Group 5.4-4', 'Header 3': '5.4.4.0 Test Group Objective', '_id': 'ab2635780bfc43a58173ddb109f194b1', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.13 Tso 5.13: Validate Input Data', 'Header 2': '5.13.1 Test Group 5.13-1', 'Header 3': '5.13.1.2 Test Case 5.13-1-2 (Functional)', 'Header 4': 'Assignment of verdict', '_id': 'b8f308750103437480f83fddf63c829f', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.13 Tso 5.13: Validate Input Data', 'Header 2': '5.13.1 Test Group 5.13-1', 'Header 3': '5.13.1.1 Test Case 5.13-1-1 (Conceptual)', 'Header 4': 'Assignment Of Verdict', '_id': '50fe2b5c34f640ba8d985741636ea217', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.0 TSO 4: Reporting implementation', 'Header 2': '5.0.1 Test group 4-1', 'Header 3': '5.0.1.1 Test Case 4-1-1 (Conceptual)', 'Header 4': 'Assignment of verdict', '_id': 'f426c4926c1449f28eb32fd523c85261', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.5 Test Group 5.1-5', 'Header 3': '5.1.5.1 Test case 5.1-5-1 (conceptual)', 'Header 4': 'Assignment of verdict', '_id': '4f303bd5fda941f08e374fc9b16194da', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.1 Test group 5.1-1', 'Header 3': '5.1.1.1 Test case 5.1-1-1 (conceptual)', 'Header 4': 'Assignment of verdict', '_id': '2ecb5e94d70c494bb3173987a0e5e8ef', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.7 Test Group 5.3-7', 'Header 3': '5.3.7.1 Test case 5.3-7-1 (conceptual)', 'Header 4': 'Test units', '_id': '45616b93a76a42a0be29718ab87923cc', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.4 Tso 5.4: Securely Store Sensitive Security Parameters', 'Header 2': '5.4.4 Test Group 5.4-4', 'Header 3': '5.4.4.1 Test case 5.4-4-1 (conceptual)', 'Header 4': 'Test units', '_id': '46bc1f282d6c4e77b145b0a897a12425', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.4 Tso 5.4: Securely Store Sensitive Security Parameters', 'Header 2': '5.4.2 Test Group 5.4-2', 'Header 3': '5.4.2.2 Test case 5.4-2-2 (functional)', 'Header 4': 'Assignment of verdict', '_id': '330b13259a71436692fb42b115212636', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.5 Tso 5.5: Communicate Securely', 'Header 2': '5.5.4 Test Group 5.5-4', 'Header 3': '5.5.4.2 Test case 5.5-4-2 (functional)', 'Header 4': 'Assignment of verdict', '_id': 'ca8ad8a7b505436b90cf8dafb49d0c52', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.6 Tso 5.6: Minimize Exposed Attack Surfaces', 'Header 2': '5.6.1 Test Group 5.6-1', 'Header 3': '5.6.1.2 Test case 5.6-1-2 (functional)', 'Header 4': 'Assignment of verdict', '_id': '378d15f5abf04cd3b35c2c026e6a52b7', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.3 Test Group 5.1-3', 'Header 3': '5.1.3.2 Test Case 5.1-3-2 (Functional)', 'Header 4': 'Assignment of verdict', '_id': 'c83ac9f0bd414b3a8c588fa36f7f6600', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.8 Tso 5.8: Ensure That Personal Data Is Secure', 'Header 2': '5.8.1 Test Group 5.8-1', 'Header 3': '5.8.1.2 Test case 5.8-1-2 (functional)', 'Header 4': 'Assignment of verdict', '_id': '5e566197dcfe4361b9b54d6fb2eaaeea', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.8 Tso 5.8: Ensure That Personal Data Is Secure', 'Header 2': 'Assignment Of Verdict', '_id': '9456610daa3247e4ac2df0fcdc54e030', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.5 Tso 5.5: Communicate Securely', 'Header 2': '5.5.1 Test Group 5.5-1', 'Header 3': '5.5.1.2 Test case 5.5-1-2 (functional)', 'Header 4': 'Assignment of verdict', '_id': '757861226e3140b2b9238e761a4d78ef', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.5 Tso 5.5: Communicate Securely', 'Header 2': '5.5.6 Test Group 5.5-6', 'Header 3': '5.5.6.2 Test case 5.5-6-2 (functional)', 'Header 4': 'Assignment of verdict', '_id': '963c0c57c91040b7b93eee49c42e9a97', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.5 Tso 5.5: Communicate Securely', 'Header 2': '5.5.7 Test Group 5.5-7', 'Header 3': '5.5.7.2 Test case 5.5-7-2 (functional)', 'Header 4': 'Assignment of verdict', '_id': 'cd166bf1752c4d00b884fc96cbd97dbf', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.4 Tso 5.4: Securely Store Sensitive Security Parameters', 'Header 2': '5.4.2 Test Group 5.4-2', 'Header 3': '5.4.2.1 Test case 5.4-2-1 (conceptual)', 'Header 4': 'Assignment of verdict', '_id': '44fae88990c14587a6a19d0945113afd', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.7 Tso 5.7: Ensure Software Integrity', 'Header 2': '5.7.2 Test Group 5.7-2', 'Header 3': '5.7.2.0 Test Group Objective', '_id': '4bb36ae5d99a4ce4992514b269060487', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.15 Test Group 5.3-15', 'Header 3': '5.3.15.1 Test case 5.3-15-1 (conceptual)', 'Header 4': 'Assignment of verdict', '_id': 'b696a561fca745aebf2d2e3fbeaee3fa', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.9 Tso 5.9: Make Systems Resilient To Outages', 'Header 2': '5.9.2 Test Group 5.9-2', 'Header 3': '5.9.2.2 Test case 5.9-2-2 (functional)', 'Header 4': 'Assignment of verdict', '_id': '3ef4595d382e48809d55d91401b3506a', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.7 Tso 5.7: Ensure Software Integrity', 'Header 2': '5.7.2 Test Group 5.7-2', 'Header 3': '5.7.2.1 Test case 5.7-2-1 (conceptual)', 'Header 4': 'Test units', '_id': '9f14d349e35f45ac810ea34bd1e01037', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.5 Tso 5.5: Communicate Securely', 'Header 2': '5.5.5 Test Group 5.5-5', 'Header 3': '5.5.5.2 Test case 5.5-5-2 (functional)', 'Header 4': 'Test units', '_id': '844092dfe9f0443eade0b0fbea4fb5cf', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.4 Tso 5.4: Securely Store Sensitive Security Parameters', 'Header 2': '5.4.3 Test Group 5.4-3', 'Header 3': '5.4.3.0 Test Group Objective', '_id': 'd3210479dc5d4ce58c984f4bcc6c54c6', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.3 Test Group 5.1-3', 'Header 3': '5.1.3.1 Test case 5.1-3-1 (conceptual)', 'Header 4': 'Test units', '_id': '289e366f48b345539bec08a17810079b', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.2 TSO 5.2: Implement a means to manage reports of vulnerabilities', 'Header 2': '5.2.2 Test Group 5.2-2', 'Header 3': '5.2.2.1 Test case 5.2-2-1 (conceptual)', 'Header 4': 'Assignment of verdict', '_id': 'cc319b15740d42c2a43f5363c2957dcb', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.9 Tso 5.9: Make Systems Resilient To Outages', 'Header 2': '5.9.1 Test Group 5.9-1', 'Header 3': '5.9.1.2 Test case 5.9-1-2 (functional)', 'Header 4': 'Assignment of verdict', '_id': 'd3f448475fac4891af401eba08ddf159', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.5 Tso 5.5: Communicate Securely', 'Header 2': '5.5.2 Test Group 5.5-2', 'Header 3': '5.5.2.2 Test Case 5.5-2-2 (Functional)', 'Header 4': 'Assignment of Verdict', '_id': '84fc05f50e2544d9beff006f988a8446', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.10 Test Group 5.3-10', 'Header 3': '5.3.10.0 Test Group Objective', '_id': '944676854e7d44f4a8d18b0ec1bdbf0c', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.13 Test group 5.3-13', 'Header 3': '5.3.13.2 Test case 5.3-13-2 (functional)', 'Header 4': 'Test units', '_id': '8d3dd3423d664d1995731c1e4cc5aa7f', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.9 Tso 5.9: Make Systems Resilient To Outages', 'Header 2': '5.9.2 Test Group 5.9-2', 'Header 3': '5.9.2.1 Test case 5.9-2-1 (conceptual)', 'Header 4': 'Assignment of verdict', '_id': '1e96180a970242d882eb65aa8e8ef546', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.1 Test group 5.1-1', 'Header 3': '5.1.1.2 Test case 5.1-1-2 (functional)', 'Header 4': 'Assignment of verdict', '_id': '2266c4caa973465e9ac5dbc7c97faeb7', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.2 TSO 5.2: Implement a means to manage reports of vulnerabilities', 'Header 2': '5.2.1 Test group 5.2-1', 'Header 3': '5.2.1.1 Test case 5.2-1-1 (conceptual)', 'Header 4': 'Assignment of verdict', '_id': '484699ffeb82402ea07f6489c7396207', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.7 Tso 5.7: Ensure Software Integrity', 'Header 2': '5.7.1 Test Group 5.7-1', 'Header 3': '5.7.1.0 Test group objective', '_id': '36f55a8aaa2b4d5ab5d7108f8cfc88f4', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.10 Tso 5.10: Examine System Telemetry Data', 'Header 2': '5.10.1 Test Group 5.10-1', 'Header 3': '5.10.1.1 Test case 5.10-1-1 (conceptual)', 'Header 4': 'Assignment of verdict', '_id': '315f876ed6084093a8c16ad98d40ae71', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.5 Tso 5.5: Communicate Securely', 'Header 2': '5.5.6 Test Group 5.5-6', 'Header 3': '5.5.6.1 Test Case 5.5-6-1 (Conceptual)', 'Header 4': 'Assignment of verdict', '_id': '05e66a22202744b8a9c02b3e5f5e9cab', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.10.1 Test Case 5.3-10-1 (Conceptual/Functional)', 'Header 4': 'Test Purpose', '_id': 'cbd20222edea444c92bb777c1a314383', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.3 Test Group 5.1-3', 'Header 3': '5.1.3.0 Test Group Objective', '_id': '2b98f3d31c504103a960801b3a087057', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.4 Tso 5.4: Securely Store Sensitive Security Parameters', 'Header 2': '5.4.1 Test Group 5.4-1', 'Header 3': '5.4.1.0 Test Group Objective', '_id': 'b8d0c6e30ddc4166a667edf41c46dadb', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.5 Tso 5.5: Communicate Securely', 'Header 2': '5.5.4 Test Group 5.5-4', 'Header 3': '5.5.4.1 Test case 5.5-4-1 (conceptual)', 'Header 4': 'Test units', '_id': '442ab17b69ed4c33846b33e4223ca9a6', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.4 Tso 5.4: Securely Store Sensitive Security Parameters', 'Header 2': '5.4.3 Test Group 5.4-3', 'Header 3': '5.4.3.1 Test case 5.4-3-1 (conceptual)', 'Header 4': 'Test units', '_id': 'c576260405c44930be447bd805db0b24', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.6 Tso 5.6: Minimize Exposed Attack Surfaces', 'Header 2': '5.6.3 Test Group 5.6-3', 'Header 3': '5.6.3.1 Test case 5.6-3-1 (conceptual)', 'Header 4': 'Assignment of verdict', '_id': '69472045bcf444e388276bd48f720f90', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.5 Tso 5.5: Communicate Securely', 'Header 2': '5.5.1 Test Group 5.5-1', 'Header 3': '5.5.1.0 Test Group Objective', '_id': '3b523111c22a40c78064446077cca449', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.6 Tso 5.6: Minimize Exposed Attack Surfaces', 'Header 2': '5.6.5 Test Group 5.6-5', 'Header 3': '5.6.5.1 Test case 5.6-5-1 (conceptual)', 'Header 4': 'Test purpose', '_id': 'e502d2347da548cd843551e10eee6bf4', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.11 Tso 5.11: Make It Easy For Users To Delete User Data', 'Header 2': '5.11.1 Test Group 5.11-1', 'Header 3': '5.11.1.2 Test case 5.11-1-2 (functional)', 'Header 4': 'Assignment of verdict', '_id': 'a55db837612a48b995d48e1e98eb5694', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.11 Tso 5.11: Make It Easy For Users To Delete User Data', 'Header 2': '5.11.3 Test Group 5.11-3', 'Header 3': '5.11.3.0 Test group objective', '_id': 'fedd8bf50b73410980e48c11c3ce4c9f', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.6 Tso 5.6: Minimize Exposed Attack Surfaces', 'Header 2': '5.6.9 Test Group 5.6-9', 'Header 3': '5.6.9.1 Test case 5.6-9-1 (conceptual)', 'Header 4': 'Test units', '_id': '5864e38c015f4e45a2c140dca67dda65', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.5 Test Group 5.1-5', 'Header 3': '5.1.5.2 Test case 5.1-5-2 (functional)', 'Header 4': 'Assignment of verdict', '_id': '978791070ea449d189534f740fdde71f', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.11 Tso 5.11: Make It Easy For Users To Delete User Data', 'Header 2': '5.11.4 Test Group 5.11-4', 'Header 3': '5.11.4.0 Test Group Objective', '_id': 'b85045659d8c469c8e0c0d72c53412de', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.2 TSO 5.2: Implement a means to manage reports of vulnerabilities', 'Header 2': '5.2.1 Test group 5.2-1', 'Header 3': '5.2.1.2 Test case 5.2-1-2 (functional)', 'Header 4': 'Assignment of verdict', '_id': '40a98457352d477caac9ff425f3e856d', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.6 Tso 5.6: Minimize Exposed Attack Surfaces', 'Header 2': '5.6.2 Test Group 5.6-2', 'Header 3': '5.6.2.0 Test Group Objective', '_id': 'fcb95f3c9c5944c0b2829ade00409d3b', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.5 Tso 5.5: Communicate Securely', 'Header 2': '5.5.1 Test Group 5.5-1', 'Header 3': '5.5.1.1 Test case 5.5-1-1 (conceptual)', 'Header 4': 'Assignment of verdict', '_id': '1d3018c2686c473d94f49d3743823f17', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.8 Test Group 5.3-8', 'Header 3': '5.3.8.0 Test Group Objective', '_id': '6f286d4e2f1746729c6b25f050b9a642', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.9 Test Group 5.3-9', 'Header 3': '5.3.9.1 Test case 5.3-9-1 (conceptual)', 'Header 4': 'Test purpose', '_id': '328cee4ca5f4441a8f07d9a156a68f8f', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.16 Test Group 5.3-16', 'Header 4': 'Assignment of verdict', '_id': 'f4365423368d4acabec617f624a367e2', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.5 Test Group 5.1-5', 'Header 3': '5.1.5.1 Test case 5.1-5-1 (conceptual)', 'Header 4': 'Test units', '_id': 'c62f8800460546139f36e87683914cfc', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.12 Tso 5.12: Make Installation And Maintenance Of Devices Easy', 'Header 2': '5.12.2 Test Group 5.12-2 5.12.2.0 Test Group Objective', '_id': 'ee9da24b35d548869fbb88c06a9289d1', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.3 Tso 5.3: Keep Software Updated', 'Header 2': '5.3.11 Test Group 5.3-11', 'Header 3': '5.3.11.1 Test case 5.3-11-1 (conceptual)', 'Header 4': 'Test Units', '_id': '97467f9cc85c4104882c51d35e65b3fe', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.4 Test Group 5.1-4', 'Header 3': '5.1.4.2 Test case 5.1-4-2 (functional)', 'Header 4': 'Test units', '_id': '5a3fc139201b464689e44e65cf7487b5', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.1 Tso 5.1: No Universal Default Passwords', 'Header 2': '5.1.1 Test group 5.1-1', 'Header 3': '5.1.1.2 Test case 5.1-1-2 (functional)', 'Header 4': 'Test units', '_id': '0f4f69ded5084811b04a31d13b0486d9', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}
# {'Header 1': '5.5 Tso 5.5: Communicate Securely', 'Header 2': '5.5.7 Test Group 5.5-7', 'Header 3': '5.5.7.1 Test case 5.5-7-1 (conceptual)', 'Header 4': 'Assignment of verdict', '_id': '294f4b7593fe4c5cbddfb113b63f5a45', '_collection_name': 'TS103701_md_hf_xiaobu_emb'}

# %% [markdown]
# ### Full test

# %%
def get_verdictList(df, topK=10):
    verdict_list = []

    # 67 個測項
    for idx in range(len(df)):

        # create a query
        row = df.iloc[idx]
        query = f"控制措施{row['provision']}，detail:{row['detail']}"
        question = f"{query}\
            How to determine PASS or FAIL from the Assignment of verdict of Test group {row['provision']}.\
            Output example: The verdict PASS is assigned if:\
            • the publication of software update support period is understandable and comprehensible for a user with limited technical knowledge. \
            The verdict FAIL is assigned otherwise. "

        # similarity search
        relevant_docs = hf_vectorstore.search(
            question, search_type="similarity", k=topK
        )

        # filter out the verdict
        verdicts = []
        for doc in relevant_docs:
            # print(doc)

            # if "Assignment of verdict" in metadata
            if "Header 4" in doc.metadata:
                if doc.metadata["Header 4"] == "Assignment of verdict":
                    # Header 2 is like 【5.1.1 Test group 5.1-1】, turn it into [5, 1, 1] to compare with the provision
                    if re.split(
                        r"[.-]", doc.metadata["Header 2"].split(" ")[-1]
                    ) == re.split(r"[.-]", row["provision"].strip()):
                        verdicts.append(doc)

        if len(verdicts) > 1:
            verdict = "The verdict PASS is assigned if:  \n"
            for item in verdicts:
                # verdict += f"{item.page_content}\n"
                splits = re.split(r"[\n]", item.page_content)
                for split in splits:
                    if split.startswith("-"):
                        verdict += f"{split}\n"
            verdict += "The verdict FAIL is assigned otherwise."
        elif len(verdicts) == 1:
            verdict = verdicts[0].page_content
        else:
            verdict = "Not found"

        verdict_list.append(verdict)

    return verdict_list

# %% [markdown]
# ## Test TopK

# %%
import pandas as pd

test_df = pd.DataFrame(columns=["topK", "Not found"])

for topK in range(10, 501, 20):
    verdict_list = get_verdictList(df, topK)
    not_found_count = verdict_list.count("Not found")
    new_row = pd.DataFrame({"topK": [topK], "Not found": [not_found_count]})
    test_df = pd.concat([test_df, new_row], ignore_index=True)
test_df
# Out:
#    topK Not found
# 0    10        42
# 1    30        24
# 2    50        19
# 3    70        15
# 4    90        11
# 5   110        10
# 6   130        10
# 7   150         9
# 8   170         9
# 9   190         9
# 10  210         9
# 11  230         9
# 12  250         9
# 13  270         9
# 14  290         9
# 15  310         9
# 16  330         9
# 17  350         9
# 18  370         9
# 19  390         9
# 20  410         9
# 21  430         9
# 22  450         9
# 23  470         9
# 24  490         9

# %%
get_verdictList(df, 150)

# drop the last row, then append the retrieved verdicts
df = df.iloc[:, :-1]
df['criteria'] = verdict_list
df
# Out:
#    provision  status  support  \
# 0     5.1-1    MC(1)      NaN
# 1      5.1-2   MC(2)      NaN
# 2      5.1-3       M      NaN
# 3      5.1-4   MC(8)      NaN
# 4      5.1-5   MC(5)      NaN
# ..       ...     ...      ...
# 62       6.1       M      NaN
# 63       6.2   MC(7)      NaN
# 64       6.3       M      NaN
# 65       6.4   RC(6)      NaN
# 66       6.5   MC(6)      NaN
#
#                                                detail  \
# 0   如果使用密碼並且處於出廠預設設置以外的任何狀態，則所有消費者物聯網設備密碼應為每個設備獨有的...
# 1   如果每台設備使用預安裝的密碼是獨有的，則應使用一種機制生成這些密碼，以降低對某種或某類設備類...
# 2          用以對裝置鑑別使用者之鑑別機制，應使用對技術、風險及使用的性質適切之最佳實務密碼學。
# 3   當使用者可以針對設備進行身份驗證時，設備應向使用者或管理員提供簡單的機制來更改所使用的身份驗證值。
# 4           當裝置係非受限制時，其應具可用之機制，使得經由網路介面暴力攻擊鑑別機制為不切實際。
# ..                                                ...
# 62  製造商應向消費者提供清晰透明的資訊，說明每個設備和服務所處理的個人資料內容、使用方式、處理者...
# 63                      處理個人資料之依據係消費者的同意，應以有效方式取得此同意。
# 64                          同意處理其個人資料的消費者有權隨時撤回其個人資料。
# 65  若由消費者 IoT 裝置及服務蒐集遙測資料，則宜將個人資料之處理保持於預期功能性所必要的最低限度。
# 66  若由消費者 IoT 裝置及服務中蒐集遙測資料，應向消費者提供有關蒐集哪些遙測資料、如何利用、...
#
#                                         Test Scenario  \
# 0   問題：當使用密碼且處於出廠預設值（例如「admin」）以外的任何狀態時，所有消費者物聯網裝置...
# 1   預先安裝的每台設備的唯一密碼應透過一種機制生成，該機制可降低針對某一類或類型設備的自動攻擊的...
# 2   身份驗證資料在使用者和裝置之間傳輸時應進行加密。\n注意：傳輸通常可以在行動應用程式和裝置之...
# 3   （範例：密碼或指紋類型的令牌）。\n\n問題：\n1. 如果設備允許使用者認證，認證值tok...
# 4   當一個設備具有物理上的限制時，可能在數據處理能力、數據通信能力、數據存儲能力或與用戶交互能力...
# ..                                                ...
# 62  許多消費者物聯網設備都會處理個人資料。 預計製造商將在消費性物聯網設備中提供支援保護此類個人...
# 63  注意：「以有效方式」取得同意通常涉及讓消費者自由、明顯和明確地選擇其個人資料是否可用於特定目...
# 64  注意：消費者希望能夠透過適當配置物聯網設備和服務功能來保護自己的隱私。問題：1. 同意處理其...
# 65  問題：\n如果遙測資料是從消費者物聯網設備和服務收集的：\n1. 個人資料的處理是否會維持在...
# 66  問題：\n如果正在收集遙測數據：\n對於從消費者物聯網設備和服務收集的遙測數據，是否會向消費...
#
#                                                answer  reason  result  \
# 0   使用者密碼透過wizard由使用者設定且與MAC Address/SN無相關性，且無法反算或...     NaN     NaN
# 1   工廠生產線上的工具為每個設備隨機產生一個密碼，將其寫入設備閃存，然後列印在標籤上，讓使用者開...     NaN     NaN
# 2   本機驗證透過 HMAC-SHA256 質詢使用使用者設定的密碼完成。 \n透過 HTTPs ...     NaN     NaN
# 3   1. 登入裝置的裝置密碼，可以在app/web介面修改，修改前必須經過管理會話身分認證。\n...     NaN     NaN
# 4       本地認證機制在連續5次錯誤登錄嘗試後鎖定API訪問60秒，這大大延長了暴力破解攻擊的時間。     NaN     NaN
# ..                                                ...     ...     ...
# 62                       設備本身並無存儲任何除了登入帳號或連線上網之外的任何資訊     NaN     NaN
# 63                                                NaN     NaN     NaN
# 64                   D-Link 除了登入的帳號密碼之外，不會存儲有關個人隱私資料。     NaN     NaN
# 65                   D-Link 除了登入的帳號密碼之外，不會存儲有關個人隱私資料。     NaN     NaN
# 66  在帳戶建立和裝置註冊過程中，所有可能透過雲端服務收集的資料都會被充分了解。 D-Link 入...     NaN     NaN
#
#                                               解釋  \
# 0                                       密碼是如何建立的
# 1                                   預設密碼的產生機制是什麼
# 2                           身份驗證資料在傳輸過程中如何進行加密保護
# 3      身份驗證後，驗證值(密碼、token..等)應有簡單的機制來更改所使用的身份驗證值
# 4                             當裝置是非受限時，要可以防止暴力破解
# ..                                           ...
# 62  製造商應向消費者說明每個設備和服務處理的個人資料內容、使用方式和目的，包括參與的第三方。
# 63                      處理個人資料需取得消費者同意，並以有效方式取得。
# 64                          消費者有權隨時撤回其個人資料處理的同意。
# 65                            處理個人資料應保持在最小必要範圍內。
# 66         製造商應向消費者提供蒐集哪些遙測資料、如何利用、利用對象及利用目的的資訊。
#
#                                              criteria
# 0   The verdict PASS is assigned if:  \n- each pas...
# 1   The verdict PASS is assigned if:  \n- no obvio...
# 2   The verdict PASS is assigned if:  \n- the secu...
# 3   The verdict PASS is assigned if:  \n- all mech...
# 4   The verdict PASS is assigned if:  \n- the docu...
# ..                                                ...
# 62  The verdict PASS is assigned if:  \n- the info...
# 63  The verdict PASS is assigned if:  \n- the way ...
# 64  The verdict PASS is assigned if for each categ...
# 65  The verdict PASS is assigned if for each telem...
# 66  The verdict PASS is assigned if:  \n- the info...
#
# [67 rows x 10 columns]

# %%
df.to_csv("../docs/test_search_verdicts_with_qdrant.csv", index=False, encoding="utf-8-sig")
